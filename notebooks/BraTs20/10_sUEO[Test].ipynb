# %%
# Cài nnU-Net bản chuẩn từ PyPI (Nhanh và sạch)
# !pip install -q nnunetv2

# Cài thêm các thư viện bổ trợ nếu thiếu
# !pip install -q nibabel matplotlib medpy pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 6.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 71.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 92.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 109.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 7.3 MB/s eta 0:00:00
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Building wheel for acvl-utils (setup.py) ... done
#   Building wheel for batchgenerators (setup.py) ... done
#   Building wheel for batchgeneratorsv2 (pyproject.toml) ... done
#   Building wheel for dynamic-network-architectures (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for medpy (setup.py) ... done

# %% [markdown]
# # A. Set up

# %% [markdown]
# ## 1. Giải nén `nnUNet_raw` & `nnUNet_preprocessed`

# %%
import os
import zipfile
from tqdm import tqdm

RAW_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_raw/Dataset101_BraTS2020.zip"
PRE_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_preprocessed/Dataset101_BraTS2020.zip"

RAW_DIR = "/content"
PRE_DIR = "/content"

def unzip(zip_path, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as z:
        for f in tqdm(z.namelist()):
            z.extract(f, out_dir)

# %%
unzip(RAW_ZIP, RAW_DIR)
# Out:
# 100%|██████████| 1848/1848 [04:13<00:00,  7.30it/s]

# %%
unzip(PRE_ZIP, PRE_DIR)
# Out:
# 100%|██████████| 2590/2590 [03:54<00:00, 11.04it/s]

# %% [markdown]
# ## 2. Set biến môi trường nnU-Net v2

# %%
import os

os.environ["nnUNet_raw"] = "/content/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = "/content/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/content/nnUNet_results"

print("nnUNet_raw:", os.environ["nnUNet_raw"])
print("nnUNet_preprocessed:", os.environ["nnUNet_preprocessed"])
print("nnUNet_results:", os.environ["nnUNet_results"])
# Out:
# nnUNet_raw: /content/nnUNet_raw
# nnUNet_preprocessed: /content/nnUNet_preprocessed
# nnUNet_results: /content/nnUNet_results

# %% [markdown]
# # B. sUEO

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_sueo.py --mode edl
# Out:
# 🚀 BẮT ĐẦU TÍNH SOFT UEO (sUEO) | CHẾ ĐỘ: EDL
# 🔍 Tìm thấy 369 ca bệnh.
#
# 📊 Lớp u: WT
# Đang xử lý WT: 100% 369/369 [33:40<00:00,  5.47s/it]
#
# 📊 Lớp u: TC
# Đang xử lý TC: 100% 369/369 [05:02<00:00,  1.22it/s]
#
# 📊 Lớp u: ET
# Đang xử lý ET: 100% 369/369 [04:50<00:00,  1.27it/s]
#
# ================================================================================
#                          🏆 BẢNG KẾT QUẢ SOFT UEO (sUEO)
# ================================================================================
# Class  sUEO_Total_Mean  sUEO_Total_Std  sUEO_Aleatoric_Mean  sUEO_Aleatoric_Std  sUEO_Epistemic_Mean  sUEO_Epistemic_Std
#    WT           0.4242          0.0474               0.4252              0.0483               0.3604              0.0613
#    TC           0.3009          0.1037               0.2933              0.1064               0.3170              0.0854
#    ET           0.2203          0.1169               0.2144              0.1163               0.2309              0.1081
#
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer__nnUNetPlans__3d_fullres/analysis_soft_sueo_results
# --------------------------------------------------------------------------------

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_sueo.py --mode edl_raw
# Out:
# 🚀 STARTING sUEO ANALYSIS | MODE: EDL_RAW
# 🔍 Found 369 cases.
#
# 📊 Class: WT
# Processing: 100% 369/369 [47:31<00:00,  7.73s/it]
#
# 📊 Class: TC
# Processing: 100% 369/369 [08:27<00:00,  1.38s/it]
#
# 📊 Class: ET
# Processing: 100% 369/369 [08:15<00:00,  1.34s/it]
#
# ================================================================================
#                              🏆 sUEO METRICS REPORT
# ================================================================================
# Class  AUC_sUEO_Total  Max_sUEO_Total  AUC_sUEO_Aleatoric  Max_sUEO_Aleatoric  AUC_sUEO_Epistemic  Max_sUEO_Epistemic
#    WT          0.2634          0.3681              0.2759              0.3685              0.1828              0.3667
#    TC          0.1919          0.2283              0.1938              0.2275              0.1732              0.2500
#    ET          0.1276          0.1557              0.1291              0.1555              0.1159              0.1599
#
# ✅ Results saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer__nnUNetPlans__3d_fullres_RAW/analysis_sueo_results
# --------------------------------------------------------------------------------
