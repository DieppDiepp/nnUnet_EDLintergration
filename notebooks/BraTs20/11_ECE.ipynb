# %%
# Cài nnU-Net bản chuẩn từ PyPI (Nhanh và sạch)
# !pip install -q nnunetv2

# Cài thêm các thư viện bổ trợ nếu thiếu
# !pip install -q nibabel matplotlib medpy pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 13.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 72.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # A. Set up

# %% [markdown]
# ## 1. Giải nén `nnUNet_raw` & `nnUNet_preprocessed`

# %%
import os
import zipfile
from tqdm import tqdm

RAW_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_raw/Dataset101_BraTS2020.zip"
PRE_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_preprocessed/Dataset101_BraTS2020.zip"

RAW_DIR = "/content"
PRE_DIR = "/content"

def unzip(zip_path, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as z:
        for f in tqdm(z.namelist()):
            z.extract(f, out_dir)

# %%
unzip(RAW_ZIP, RAW_DIR)
# Out:
# 100%|██████████| 1848/1848 [04:59<00:00,  6.18it/s]

# %%
# unzip(PRE_ZIP, PRE_DIR)

# %% [markdown]
# ## 2. Set biến môi trường nnU-Net v2

# %%
import os

os.environ["nnUNet_raw"] = "/content/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = "/content/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results"

print("nnUNet_raw:", os.environ["nnUNet_raw"])
print("nnUNet_preprocessed:", os.environ["nnUNet_preprocessed"])
print("nnUNet_results:", os.environ["nnUNet_results"])
# Out:
# nnUNet_raw: /content/nnUNet_raw
# nnUNet_preprocessed: /content/nnUNet_preprocessed
# nnUNet_results: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results

# %% [markdown]
# # B. ECE - 15 bins

# %% [markdown]
# ## 1. EDL with engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode edl
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: EDL
# Đang gom dữ liệu Confidence: 100% 369/369 [15:54<00:00,  2.59s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel)...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 0.7300 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer__nnUNetPlans__3d_fullres/analysis_ece_results

# %% [markdown]
# ## 2. EDL without engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode edl_raw
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: EDL_RAW
# Đang gom dữ liệu Confidence: 100% 369/369 [27:44<00:00,  4.51s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel)...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 0.7283 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer__nnUNetPlans__3d_fullres_RAW/analysis_ece_results

# %% [markdown]
# ## 3. Baseline with engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode baseline
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: BASELINE
# Đang gom dữ liệu Confidence: 100% 369/369 [25:28<00:00,  4.14s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel)...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 1.5361 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/analysis_ece_results

# %% [markdown]
# ## 4. Baseline without engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode baseline_raw
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: BASELINE_RAW
# Đang gom dữ liệu Confidence: 100% 369/369 [27:25<00:00,  4.46s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel)...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 1.6002 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres_RAW/analysis_ece_results

# %% [markdown]
# ## EDL with engine - 250 epochs

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode edl_250 --bins 15
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: EDL_250 | BINS: 15
# Đang gom dữ liệu Confidence: 100% 369/369 [15:05<00:00,  2.45s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 15 bins...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 0.8056 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_250epochs__nnUNetPlans__3d_fullres/analysis_ece_results

# %% [markdown]
# # C. ECE - 10 Bins

# %% [markdown]
# ## 1. EDL with engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode edl --bins 10
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: EDL | BINS: 10
# Đang gom dữ liệu Confidence: 100% 369/369 [29:11<00:00,  4.75s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 0.6164 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer__nnUNetPlans__3d_fullres/analysis_ece_results

# %% [markdown]
# ## 2. EDL without engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode edl_raw --bins 10
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: EDL_RAW | BINS: 10
# Đang gom dữ liệu Confidence: 100% 369/369 [02:58<00:00,  2.07it/s]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 0.6508 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer__nnUNetPlans__3d_fullres_RAW/analysis_ece_results

# %% [markdown]
# ## 3. Baseline with engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode baseline --bins 10
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: BASELINE | BINS: 10
# Đang gom dữ liệu Confidence: 100% 369/369 [02:37<00:00,  2.35it/s]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 1.5362 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/analysis_ece_results

# %% [markdown]
# ## 4. Baseline without engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode baseline_raw --bins 10
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: BASELINE_RAW | BINS: 10
# Đang gom dữ liệu Confidence: 100% 369/369 [02:44<00:00,  2.24it/s]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 1.6003 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres_RAW/analysis_ece_results

# %% [markdown]
# ## 5. EDL 250 with engine - 250 epochs

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode edl_250 --bins 10
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: EDL_250 | BINS: 10
# Đang gom dữ liệu Confidence: 100% 369/369 [02:19<00:00,  2.65it/s]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ...
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ...
# Overall ECE Score: 0.8054 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_250epochs__nnUNetPlans__3d_fullres/analysis_ece_results
