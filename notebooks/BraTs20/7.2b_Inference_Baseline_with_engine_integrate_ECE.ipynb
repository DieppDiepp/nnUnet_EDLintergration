# %%
# Cài nnU-Net bản chuẩn từ PyPI (Nhanh và sạch)
# !pip install -q nnunetv2

# Cài thêm các thư viện bổ trợ nếu thiếu
# !pip install -q nibabel matplotlib medpy pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 20.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 42.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 113.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 12.5 MB/s eta 0:00:00
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Building wheel for acvl-utils (setup.py) ... done
#   Building wheel for batchgenerators (setup.py) ... done
#   Building wheel for batchgeneratorsv2 (pyproject.toml) ... done
#   Building wheel for dynamic-network-architectures (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for medpy (setup.py) ... done

# %%
# !nvidia-smi
# Out:
# Tue Mar  3 01:17:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   41C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # A. Set up

# %% [markdown]
# ## 1. Giải nén `nnUNet_raw` & `nnUNet_preprocessed`

# %%
import os
import zipfile
from tqdm import tqdm

RAW_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_raw/Dataset101_BraTS2020.zip"
PRE_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_preprocessed/Dataset101_BraTS2020.zip"

RAW_DIR = "/content"
PRE_DIR = "/content"

def unzip(zip_path, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as z:
        for f in tqdm(z.namelist()):
            z.extract(f, out_dir)

# %%
unzip(RAW_ZIP, RAW_DIR)
# Out:
# 100%|██████████| 1848/1848 [02:01<00:00, 15.26it/s]

# %%
unzip(PRE_ZIP, PRE_DIR)
# Out:
# 100%|██████████| 2590/2590 [04:40<00:00,  9.23it/s]

# %% [markdown]
# ## 2. Set biến môi trường nnU-Net v2

# %%
import os

os.environ["nnUNet_raw"] = "/content/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = "/content/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/content/nnUNet_results"

print("nnUNet_raw:", os.environ["nnUNet_raw"])
print("nnUNet_preprocessed:", os.environ["nnUNet_preprocessed"])
print("nnUNet_results:", os.environ["nnUNet_results"])
# Out:
# nnUNet_raw: /content/nnUNet_raw
# nnUNet_preprocessed: /content/nnUNet_preprocessed
# nnUNet_results: /content/nnUNet_results

# %% [markdown]
# # B. Inference Baseline

# %%
# CHẾ ĐỘ 1: CHẠY MODEL EDL (UNCERTAINTY DECOMPOSITION)
# ------------------------------------------------------------------
# Script này sẽ thực hiện quy trình full:
# 1. Tự động "tiêm" (inject) file EDLTrainer.py vào thư viện nnU-Net hệ thống.
# 2. Load trọng số Model EDL (checkpoint_best.pth) từ đường dẫn config 'edl'.
# 3. Chạy Inference và tính toán toán học để tách Uncertainty thành:
#    - Aleatoric (Nhiễu dữ liệu)
#    - Epistemic (Mô hình chưa biết)
# 4. Lưu kết quả Segmentation + 3 bản đồ Uncertainty (.nii.gz).

# %%
# Đổi tên file cho đúng chuẩn (giải nén còn thừa .gz)
# !for f in /content/nnUNet_raw/Dataset101_BraTS2020/imagesTr/*.nii.gz; do mv "$f" "${f%.gz}"; done

# %% [markdown]
# ## 1. Fold 0

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode baseline --fold 0 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: BASELINE | FOLD: 0 ---
# 🔧 Initializing Engine | Mode: BASELINE...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 0: 74 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 74 cases (Filtered).
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_011...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_011.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_011.nii -> KHÔNG
# 100% 8/8 [00:05<00:00,  1.46it/s]
# 1        | BRATS_011       | 0.9187   | 0.9181   | 0.7747   | 0.8705
#     📸 Drawing Slice: 112
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_011_slice112_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_012...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_012.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_012.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.19it/s]
# 2        | BRATS_012       | 0.8600   | 0.9186   | 0.8240   | 0.8675
#     📸 Drawing Slice: 119
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_012_slice119_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_019...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_019.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_019.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.18it/s]
# 3        | BRATS_019       | 0.9046   | 0.9189   | 0.8028   | 0.8754
#     📸 Drawing Slice: 104
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_019_slice104_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_020...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_020.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_020.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.17it/s]
# 4        | BRATS_020       | 0.9020   | 0.8697   | 0.7191   | 0.8302
#     📸 Drawing Slice: 45
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_020_slice45_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_021...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_021.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_021.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.17it/s]
# 5        | BRATS_021       | 0.8127   | 0.9112   | 0.7809   | 0.8349
#     📸 Drawing Slice: 58
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_021_slice58_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_023...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_023.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_023.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.34it/s]
# 6        | BRATS_023       | 0.9085   | 0.9487   | 0.8666   | 0.9079
#     📸 Drawing Slice: 83
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_023_slice83_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_028...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_028.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_028.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.17it/s]
# 7        | BRATS_028       | 0.8430   | 0.8623   | 0.6660   | 0.7904
#     📸 Drawing Slice: 114
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_028_slice114_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_029...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_029.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_029.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.16it/s]
# 8        | BRATS_029       | 0.9347   | 0.9386   | 0.8736   | 0.9156
#     📸 Drawing Slice: 33
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_029_slice33_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_032...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_032.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_032.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.16it/s]
# 9        | BRATS_032       | 0.8991   | 0.9013   | 0.7974   | 0.8659
#     📸 Drawing Slice: 82
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_032_slice82_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_036...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_036.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_036.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.15it/s]
# 10       | BRATS_036       | 0.8845   | 0.8756   | 0.7991   | 0.8531
#     📸 Drawing Slice: 122
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_036_slice122_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_039...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_039.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_039.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.31it/s]
# 11       | BRATS_039       | 0.9176   | 0.9358   | 0.8789   | 0.9108
#     📸 Drawing Slice: 98
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_039_slice98_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_041...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_041.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_041.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.14it/s]
# 12       | BRATS_041       | 0.9451   | 0.9000   | 0.7650   | 0.8700
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_041_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_042...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_042.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_042.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.14it/s]
# 13       | BRATS_042       | 0.9579   | 0.9606   | 0.8701   | 0.9296
#     📸 Drawing Slice: 89
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_042_slice89_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_049...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_049.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_049.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.14it/s]
# 14       | BRATS_049       | 0.9135   | 0.9537   | 0.8826   | 0.9166
#     📸 Drawing Slice: 95
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_049_slice95_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_051...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_051.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_051.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.13it/s]
# 15       | BRATS_051       | 0.9422   | 0.9401   | 0.8819   | 0.9214
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_051_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_053...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_053.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_053.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.12it/s]
# 16       | BRATS_053       | 0.9558   | 0.8715   | 0.8343   | 0.8872
#     📸 Drawing Slice: 32
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_053_slice32_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_056...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_056.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_056.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.28it/s]
# 17       | BRATS_056       | 0.8708   | 0.9202   | 0.8685   | 0.8865
#     📸 Drawing Slice: 52
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_056_slice52_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_069...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_069.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_069.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.28it/s]
# 18       | BRATS_069       | 0.7706   | 0.9476   | 0.8442   | 0.8541
#     📸 Drawing Slice: 81
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_069_slice81_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_074...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_074.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_074.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.12it/s]
# 19       | BRATS_074       | 0.8182   | 0.5251   | 0.3599   | 0.5677
#     📸 Drawing Slice: 94
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_074_slice94_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_086...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_086.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_086.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.11it/s]
# 20       | BRATS_086       | 0.7537   | 0.3179   | 0.2891   | 0.4536
#     📸 Drawing Slice: 9
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_086_slice9_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_088...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_088.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_088.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.11it/s]
# 21       | BRATS_088       | 0.8501   | 0.9012   | 0.8045   | 0.8519
#     📸 Drawing Slice: 32
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_088_slice32_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_089...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_089.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_089.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 22       | BRATS_089       | 0.8499   | 0.9613   | 0.9587   | 0.9233
#     📸 Drawing Slice: 98
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_089_slice98_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_098...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_098.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_098.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 23       | BRATS_098       | 0.9788   | 0.9618   | 0.9129   | 0.9512
#     📸 Drawing Slice: 56
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_098_slice56_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_100...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_100.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_100.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 24       | BRATS_100       | 0.9647   | 0.9649   | 0.8993   | 0.9430
#     📸 Drawing Slice: 36
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_100_slice36_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_101...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_101.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_101.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 25       | BRATS_101       | 0.9186   | 0.9029   | 0.8741   | 0.8985
#     📸 Drawing Slice: 108
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_101_slice108_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_104...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_104.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_104.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 26       | BRATS_104       | 0.9669   | 0.9665   | 0.9403   | 0.9579
#     📸 Drawing Slice: 29
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_104_slice29_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_107...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_107.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_107.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 27       | BRATS_107       | 0.9512   | 0.9629   | 0.9641   | 0.9594
#     📸 Drawing Slice: 86
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_107_slice86_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_111...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_111.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_111.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 28       | BRATS_111       | 0.9447   | 0.9644   | 0.9238   | 0.9443
#     📸 Drawing Slice: 30
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_111_slice30_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_113...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_113.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_113.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 29       | BRATS_113       | 0.9624   | 0.6347   | 0.8140   | 0.8037
#     📸 Drawing Slice: 29
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_113_slice29_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_114...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_114.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_114.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 30       | BRATS_114       | 0.9471   | 0.9726   | 0.9200   | 0.9465
#     📸 Drawing Slice: 85
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_114_slice85_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_116...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_116.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_116.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 31       | BRATS_116       | 0.9698   | 0.9773   | 0.9326   | 0.9599
#     📸 Drawing Slice: 37
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_116_slice37_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_131...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_131.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_131.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 32       | BRATS_131       | 0.9286   | 0.8676   | 0.8939   | 0.8967
#     📸 Drawing Slice: 86
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_131_slice86_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_137...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_137.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_137.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 33       | BRATS_137       | 0.9413   | 0.9432   | 0.8744   | 0.9196
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_137_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_138...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_138.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_138.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 34       | BRATS_138       | 0.9392   | 0.8206   | 0.8931   | 0.8843
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_138_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_145...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_145.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_145.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 35       | BRATS_145       | 0.9313   | 0.9368   | 0.8216   | 0.8966
#     📸 Drawing Slice: 109
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_145_slice109_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_150...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_150.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_150.nii -> KHÔNG
# 100% 2/2 [00:00<00:00,  2.63it/s]
# 36       | BRATS_150       | 0.9541   | 0.9639   | 0.9550   | 0.9577
#     📸 Drawing Slice: 87
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_150_slice87_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_155...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_155.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_155.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 37       | BRATS_155       | 0.9652   | 0.9667   | 0.9427   | 0.9582
#     📸 Drawing Slice: 87
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_155_slice87_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_162...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_162.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_162.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 38       | BRATS_162       | 0.9527   | 0.9734   | 0.9486   | 0.9582
#     📸 Drawing Slice: 52
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_162_slice52_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_165...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_165.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_165.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 39       | BRATS_165       | 0.9623   | 0.9497   | 0.9293   | 0.9471
#     📸 Drawing Slice: 101
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_165_slice101_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_174...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_174.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_174.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 40       | BRATS_174       | 0.9746   | 0.9510   | 0.9320   | 0.9525
#     📸 Drawing Slice: 96
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS
nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 61       | BRATS_245       | 0.9281   | 0.9071   | 0.8098   | 0.8817
#     📸 Drawing Slice: 92
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_245_slice92_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_251...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_251.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_251.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 62       | BRATS_251       | 0.9590   | 0.9418   | 0.9458   | 0.9489
#     📸 Drawing Slice: 101
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_251_slice101_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_259...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_259.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_259.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 63       | BRATS_259       | 0.9652   | 0.3206   | 0.8438   | 0.7099
#     📸 Drawing Slice: 41
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_259_slice41_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_284...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_284.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_284.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 64       | BRATS_284       | 0.9326   | 0.8595   | 0.5989   | 0.7970
#     📸 Drawing Slice: 62
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_284_slice62_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_287...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_287.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_287.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 65       | BRATS_287       | 0.9695   | 0.9153   | 0.9129   | 0.9326
#     📸 Drawing Slice: 27
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_287_slice27_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_297...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_297.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_297.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 66       | BRATS_297       | 0.6731   | 0.5854   | 1.0000   | 0.7528
#     📸 Drawing Slice: 91
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_297_slice91_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_302...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_302.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_302.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 67       | BRATS_302       | 0.8647   | 0.8340   | 0.6574   | 0.7854
#     📸 Drawing Slice: 23
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_302_slice23_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_305...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_305.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_305.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 68       | BRATS_305       | 0.9467   | 0.8728   | 0.0000   | 0.6065
#     📸 Drawing Slice: 50
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_305_slice50_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_329...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_329.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_329.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 69       | BRATS_329       | 0.9112   | 0.6050   | 0.0000   | 0.5054
#     📸 Drawing Slice: 39
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_329_slice39_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_331...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_331.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_331.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 70       | BRATS_331       | 0.8471   | 0.7238   | 0.7847   | 0.7852
#     📸 Drawing Slice: 112
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_331_slice112_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_342...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_342.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_342.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 71       | BRATS_342       | 0.9237   | 0.9450   | 0.8700   | 0.9129
#     📸 Drawing Slice: 46
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_342_slice46_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_353...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_353.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_353.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 72       | BRATS_353       | 0.9708   | 0.9638   | 0.9175   | 0.9507
#     📸 Drawing Slice: 101
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_353_slice101_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_360...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_360.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_360.nii -> KHÔNG
# 100% 2/2 [00:00<00:00,  2.65it/s]
# 73       | BRATS_360       | 0.9401   | 0.9689   | 0.9418   | 0.9503
#     📸 Drawing Slice: 38
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_360_slice38_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_368...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_368.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_368.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 74       | BRATS_368       | 0.9474   | 0.9542   | 0.9298   | 0.9438
#     📸 Drawing Slice: 105
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_368_slice105_viz.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9199     | 0.8903     | 0.8277
# HD95 (mm)       | 5.4198     | 4.9512     | 13.8575
# ------------------------------------------------------------
# Overall Mean Dice: 0.8793
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/metrics_summary/metrics_summary_fold0.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ## 2. Fold 1

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode baseline --fold 1 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: BASELINE | FOLD: 1 ---
# 🔧 Initializing Engine | Mode: BASELINE...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 1: 74 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 74 cases (Filtered).
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_004...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_004.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_004.nii -> KHÔNG
# 100% 8/8 [00:04<00:00,  1.61it/s]
# 1        | BRATS_004       | 0.9506   | 0.9158   | 0.8892   | 0.9186
#     📸 Drawing Slice: 98
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_004_slice98_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_005...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_005.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_005.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 2        | BRATS_005       | 0.8674   | 0.9252   | 0.8282   | 0.8736
#     📸 Drawing Slice: 110
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_005_slice110_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_009...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_009.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_009.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 3        | BRATS_009       | 0.9014   | 0.8514   | 0.7182   | 0.8237
#     📸 Drawing Slice: 41
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_009_slice41_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_015...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_015.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_015.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 4        | BRATS_015       | 0.9453   | 0.7850   | 0.8577   | 0.8627
#     📸 Drawing Slice: 106
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_015_slice106_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_017...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_017.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_017.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 5        | BRATS_017       | 0.9313   | 0.8745   | 0.8444   | 0.8834
#     📸 Drawing Slice: 115
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_017_slice115_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_022...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_022.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_022.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 6        | BRATS_022       | 0.9470   | 0.9404   | 0.8798   | 0.9224
#     📸 Drawing Slice: 78
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_022_slice78_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_031...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_031.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_031.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 7        | BRATS_031       | 0.9100   | 0.9260   | 0.8756   | 0.9039
#     📸 Drawing Slice: 90
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_031_slice90_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_034...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_034.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_034.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 8        | BRATS_034       | 0.9466   | 0.9373   | 0.8305   | 0.9048
#     📸 Drawing Slice: 78
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_034_slice78_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_043...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_043.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_043.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 9        | BRATS_043       | 0.8379   | 0.8708   | 0.6500   | 0.7862
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_043_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_046...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_046.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_046.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 10       | BRATS_046       | 0.6063   | 0.8738   | 0.8359   | 0.7720
#     📸 Drawing Slice: 94
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_046_slice94_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_047...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_047.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_047.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 11       | BRATS_047       | 0.9070   | 0.9497   | 0.8655   | 0.9074
#     📸 Drawing Slice: 69
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_047_slice69_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_048...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_048.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_048.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 12       | BRATS_048       | 0.7029   | 0.9064   | 0.7713   | 0.7935
#     📸 Drawing Slice: 109
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_048_slice109_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_054...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_054.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_054.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 13       | BRATS_054       | 0.9149   | 0.9423   | 0.8995   | 0.9189
#     📸 Drawing Slice: 31
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_054_slice31_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_055...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_055.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_055.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 14       | BRATS_055       | 0.9476   | 0.9510   | 0.8561   | 0.9182
#     📸 Drawing Slice: 113
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_055_slice113_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_058...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_058.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_058.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 15       | BRATS_058       | 0.8218   | 0.8146   | 0.5981   | 0.7449
#     📸 Drawing Slice: 110
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_058_slice110_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_068...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_068.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_068.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 16       | BRATS_068       | 0.9355   | 0.9103   | 0.8395   | 0.8951
#     📸 Drawing Slice: 90
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_068_slice90_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_072...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_072.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_072.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 17       | BRATS_072       | 0.8077   | 0.9444   | 0.8948   | 0.8823
#     📸 Drawing Slice: 103
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_072_slice103_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_076...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_076.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_076.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 18       | BRATS_076       | 0.9071   | 0.8632   | 0.7949   | 0.8550
#     📸 Drawing Slice: 42
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_076_slice42_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_091...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_091.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_091.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 19       | BRATS_091       | 0.8982   | 0.9665   | 0.9431   | 0.9359
#     📸 Drawing Slice: 97
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_091_slice97_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_102...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_102.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_102.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 20       | BRATS_102       | 0.9319   | 0.9433   | 0.8728   | 0.9160
#     📸 Drawing Slice: 76
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_102_slice76_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_115...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_115.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_115.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 21       | BRATS_115       | 0.9602   | 0.9779   | 0.9615   | 0.9665
#     📸 Drawing Slice: 51
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_115_slice51_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_121...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_121.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_121.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 22       | BRATS_121       | 0.9771   | 0.9809   | 0.9420   | 0.9667
#     📸 Drawing Slice: 103
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_121_slice103_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_129...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_129.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_129.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 23       | BRATS_129       | 0.9404   | 0.8202   | 0.8269   | 0.8625
#     📸 Drawing Slice: 35
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS
nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 65       | BRATS_339       | 0.9452   | 0.9711   | 0.9474   | 0.9546
#     📸 Drawing Slice: 48
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_339_slice48_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_340...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_340.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_340.nii -> KHÔNG
# 100% 12/12 [00:05<00:00,  2.04it/s]
# 66       | BRATS_340       | 0.9739   | 0.9721   | 0.9558   | 0.9673
#     📸 Drawing Slice: 59
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_340_slice59_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_341...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_341.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_341.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 67       | BRATS_341       | 0.9227   | 0.9354   | 0.9321   | 0.9301
#     📸 Drawing Slice: 123
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_341_slice123_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_343...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_343.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_343.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 68       | BRATS_343       | 0.9411   | 0.9523   | 0.9159   | 0.9365
#     📸 Drawing Slice: 34
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_343_slice34_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_345...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_345.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_345.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 69       | BRATS_345       | 0.8858   | 0.8985   | 0.8864   | 0.8902
#     📸 Drawing Slice: 43
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_345_slice43_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_352...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_352.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_352.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 70       | BRATS_352       | 0.9490   | 0.9387   | 0.9149   | 0.9342
#     📸 Drawing Slice: 35
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_352_slice35_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_355...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_355.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_355.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 71       | BRATS_355       | 0.9702   | 0.9756   | 0.9513   | 0.9657
#     📸 Drawing Slice: 55
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_355_slice55_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_357...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_357.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_357.nii -> KHÔNG
# 100% 2/2 [00:00<00:00,  2.66it/s]
# 72       | BRATS_357       | 0.9305   | 0.9319   | 0.8485   | 0.9036
#     📸 Drawing Slice: 38
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_357_slice38_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_359...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_359.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_359.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 73       | BRATS_359       | 0.9719   | 0.9740   | 0.9436   | 0.9631
#     📸 Drawing Slice: 30
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_359_slice30_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_369...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_369.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_369.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 74       | BRATS_369       | 0.9675   | 0.9557   | 0.9464   | 0.9565
#     📸 Drawing Slice: 63
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_369_slice63_viz.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9245     | 0.9084     | 0.7917
# HD95 (mm)       | 4.1515     | 3.2499     | 32.7022
# ------------------------------------------------------------
# Overall Mean Dice: 0.8748
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/metrics_summary/metrics_summary_fold1.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ## 3. Fold 2

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode baseline --fold 2 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: BASELINE | FOLD: 2 ---
# 🔧 Initializing Engine | Mode: BASELINE...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 2: 74 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 74 cases (Filtered).
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_002...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_002.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_002.nii -> KHÔNG
# 100% 8/8 [00:04<00:00,  1.61it/s]
# 1        | BRATS_002       | 0.9090   | 0.9604   | 0.8614   | 0.9103
#     📸 Drawing Slice: 34
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_002_slice34_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_008...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_008.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_008.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 2        | BRATS_008       | 0.8317   | 0.8393   | 0.8238   | 0.8316
#     📸 Drawing Slice: 38
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_008_slice38_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_010...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_010.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_010.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 3        | BRATS_010       | 0.8408   | 0.8906   | 0.8572   | 0.8629
#     📸 Drawing Slice: 26
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_010_slice26_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_016...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_016.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_016.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 4        | BRATS_016       | 0.9166   | 0.8786   | 0.7255   | 0.8403
#     📸 Drawing Slice: 31
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_016_slice31_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_018...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_018.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_018.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 5        | BRATS_018       | 0.8212   | 0.8648   | 0.8210   | 0.8356
#     📸 Drawing Slice: 45
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_018_slice45_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_026...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_026.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_026.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
#
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_257_slice27_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_263...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_263.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_263.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 48       | BRATS_263       | 0.8946   | 0.6731   | 0.0000   | 0.5226
#     📸 Drawing Slice: 78
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_263_slice78_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_270...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_270.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_270.nii -> KHÔNG
# 100% 2/2 [00:00<00:00,  2.66it/s]
# 49       | BRATS_270       | 0.9701   | 0.9807   | 0.9717   | 0.9742
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_270_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_271...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_271.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_271.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 50       | BRATS_271       | 0.9586   | 0.9445   | 0.7429   | 0.8820
#     📸 Drawing Slice: 42
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_271_slice42_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_273...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_273.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_273.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 51       | BRATS_273       | 0.9381   | 0.9060   | 0.5572   | 0.8005
#     📸 Drawing Slice: 87
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_273_slice87_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_275...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_275.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_275.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 52       | BRATS_275       | 0.8482   | 0.5591   | 0.0000   | 0.4691
#     📸 Drawing Slice: 102
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_275_slice102_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_276...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_276.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_276.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 53       | BRATS_276       | 0.9248   | 0.8991   | 0.8679   | 0.8973
#     📸 Drawing Slice: 44
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_276_slice44_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_285...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_285.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_285.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 54       | BRATS_285       | 0.9676   | 0.9420   | 0.7734   | 0.8943
#     📸 Drawing Slice: 84
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_285_slice84_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_293...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_293.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_293.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 55       | BRATS_293       | 0.9227   | 0.7955   | 0.9001   | 0.8728
#     📸 Drawing Slice: 47
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_293_slice47_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_300...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_300.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_300.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 56       | BRATS_300       | 0.9279   | 0.7917   | 0.8890   | 0.8695
#     📸 Drawing Slice: 83
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_300_slice83_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_301...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_301.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_301.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 57       | BRATS_301       | 0.9029   | 0.7531   | 0.7665   | 0.8075
#     📸 Drawing Slice: 82
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_301_slice82_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_307...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_307.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_307.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 58       | BRATS_307       | 0.9286   | 0.9056   | 0.0000   | 0.6114
#     📸 Drawing Slice: 41
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_307_slice41_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_312...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_312.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_312.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 59       | BRATS_312       | 0.9176   | 0.7771   | 0.0000   | 0.5649
#     📸 Drawing Slice: 78
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_312_slice78_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_317...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_317.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_317.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 60       | BRATS_317       | 0.9445   | 0.8857   | 0.8899   | 0.9067
#     📸 Drawing Slice: 125
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_317_slice125_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_320...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_320.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_320.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 61       | BRATS_320       | 0.8549   | 0.9080   | 0.8708   | 0.8779
#     📸 Drawing Slice: 31
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_320_slice31_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_321...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_321.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_321.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 62       | BRATS_321       | 0.9497   | 0.8312   | 1.0000   | 0.9270
#     📸 Drawing Slice: 83
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_321_slice83_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_322...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_322.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_322.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 63       | BRATS_322       | 0.9749   | 0.9220   | 0.4195   | 0.7721
#     📸 Drawing Slice: 103
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_322_slice103_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_326...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_326.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_326.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 64       | BRATS_326       | 0.8917   | 0.6357   | 0.3399   | 0.6224
#     📸 Drawing Slice: 88
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_326_slice88_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_334...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_334.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_334.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 65       | BRATS_334       | 0.9610   | 0.8918   | 0.8867   | 0.9132
#     📸 Drawing Slice: 30
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_334_slice30_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_346...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_346.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_346.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 66       | BRATS_346       | 0.9716   | 0.9812   | 0.9321   | 0.9616
#     📸 Drawing Slice: 67
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_346_slice67_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_347...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_347.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_347.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 67       | BRATS_347       | 0.9753   | 0.9720   | 0.9556   | 0.9676
#     📸 Drawing Slice: 54
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_347_slice54_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_350...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_350.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_350.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 68       | BRATS_350       | 0.9769   | 0.9779   | 0.9608   | 0.9719
#     📸 Drawing Slice: 50
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_350_slice50_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_351...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_351.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_351.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 69       | BRATS_351       | 0.9558   | 0.9707   | 0.9513   | 0.9593
#     📸 Drawing Slice: 107
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_351_slice107_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_354...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_354.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_354.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 70       | BRATS_354       | 0.9558   | 0.9568   | 0.9331   | 0.9486
#     📸 Drawing Slice: 46
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_354_slice46_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_356...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_356.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_356.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 71       | BRATS_356       | 0.9277   | 0.9519   | 0.9125   | 0.9307
#     📸 Drawing Slice: 92
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_356_slice92_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_361...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_361.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_361.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 72       | BRATS_361       | 0.9646   | 0.3674   | 0.0071   | 0.4463
#     📸 Drawing Slice: 89
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_361_slice89_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_362...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_362.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_362.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 73       | BRATS_362       | 0.9698   | 0.9680   | 0.9243   | 0.9540
#     📸 Drawing Slice: 102
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_362_slice102_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_364...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_364.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_364.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 74       | BRATS_364       | 0.9510   | 0.9493   | 0.9045   | 0.9349
#     📸 Drawing Slice: 34
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_364_slice34_viz.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9312     | 0.8963     | 0.8059
# HD95 (mm)       | 2.8985     | 3.1255     | 17.9624
# ------------------------------------------------------------
# Overall Mean Dice: 0.8778
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/metrics_summary/metrics_summary_fold2.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ## 4. Fold 3

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode baseline --fold 3 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: BASELINE | FOLD: 3 ---
# 🔧 Initializing Engine | Mode: BASELINE...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 3: 74 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 74 cases (Filtered).
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_003...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_003.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_003.nii -> KHÔNG
# 100% 8/8 [00:04<00:00,  1.61it/s]
# 1        | BRATS_003       | 0.8207   | 0.9161   | 0.8598   | 0.8655
#     📸 Drawing Slice: 95
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_003_slice95_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_007...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_007.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_007.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 2        | BRATS_007       | 0.9216   | 0.9327   | 0.8892   | 0.9145
#     📸 Drawing Slice: 114
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_007_slice114_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_014...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_014.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_014.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 3        | BRATS_014       | 0.9161   | 0.9181   | 0.8402   | 0.8915
#     📸 Drawing Slice: 31
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_014_slice31_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_025...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_025.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_025.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 4        | BRATS_025       | 0.9264   | 0.9695   | 0.9016   | 0.9325
#     📸 Drawing Slice: 84
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_025_slice84_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_033...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_033.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_033.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 5        | BRATS_033       | 0.9556   | 0.9554   | 0.9107   | 0.9406
#     📸 Drawing Slice: 44
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_033_slice44_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_052...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_052.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_052.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 6        | BRATS_052       | 0.9137   | 0.9446   | 0.8682   | 0.9088
#     📸 Drawing Slice: 55
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_052_slice55_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_062...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_062.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_062.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 7        | BRATS_062       | 0.9512   | 0.9638   | 0.8983   | 0.9378
#     📸 Drawing Slice: 42
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_062_slice42_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_066...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_066.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_066.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 8        | BRATS_066       | 0.9417   | 0.9198   | 0.8181   | 0.8932
#     📸 Drawing Slice: 38
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_066_slice38_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_070...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_070.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_070.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 9        | BRATS_070       | 0.9187   | 0.8955   | 0.7760   | 0.8634
#     📸 Drawing Slice: 44
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_070_slice44_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_079...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_079.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_079.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 10       | BRATS_079       | 0.8509   | 0.8319   | 0.7912   | 0.8246
#     📸 Drawing Slice: 35
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_079_slice35_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_080...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_080.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_080.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 11       | BRATS_080       | 0.8920   | 0.8480   | 0.8349   | 0.8583
#     📸 Drawing Slice: 36
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_080_slice36_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_085...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_085.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_085.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 12       | BRATS_085       | 0.9066   | 0.8836   | 0.7511   | 0.8471
#     📸 Drawing Slice: 81
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_085_slice81_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_087...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_087.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_087.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 13       | BRATS_087       | 0.8508   | 0.7673   | 0.5155   | 0.7112
#     📸 Drawing Slice: 118
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_087_slice118_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_095...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_095.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_095.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 14       | BRATS_095       | 0.9735   | 0.9155   | 0.8733   | 0.9208
#     📸 Drawing Slice: 68
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_095_slice68_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_097...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_097.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_097.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 15       | BRATS_097       | 0.9622   | 0.9718   | 0.9249   | 0.9530
#     📸 Drawing Slice: 32
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_097_slice32_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_099...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_099.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_099.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 16       | BRATS_099       | 0.8090   | 0.9270   | 0.9270   | 0.8877
#     📸 Drawing Slice: 99
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_099_slice99_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_103...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_103.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_103.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 17       | BRATS_103       | 0.9337   | 0.9585   | 0.9042   | 0.9321
#     📸 Drawing Slice: 112
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_103_slice112_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_110...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_110.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_110.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 18       | BRATS_110       | 0.8431   | 0.8939   | 0.8825   | 0.8731
#     📸 Drawing Slice: 80
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_110_slice80_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_112...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_112.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_112.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 19       | BRATS_112       | 0.9732   | 0.9844   | 0.9629   | 0.9735
#     📸 Drawing Slice: 44
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_112_slice44_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_117...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_117.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_117.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 20       | BRATS_117       | 0.9579   | 0.9714   | 0.9480   | 0.9591
#     📸 Drawing Slice: 102
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_117_slice102_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_122...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_122.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_122.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 21       | BRATS_122       | 0.9620   | 0.9690   | 0.9443   | 0.9584
#     📸 Drawing Slice: 114
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_122_slice114_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_126...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_126.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_126.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 22       | BRATS_126       | 0.9272   | 0.9378   | 0.9209   | 0.9286
#     📸 Drawing Slice: 18
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_126_slice18_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_127...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_127.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_127.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 23       | BRATS_127       | 0.9702   | 0.9731   | 0.9694   | 0.9709
#     📸 Drawing Slice: 114
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_127_slice114_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_132...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_132.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_132.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 24       | BRATS_132       | 0.9205   | 0.9312   | 0.9158   | 0.9225
#     📸 Drawing Slice: 50
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_132_slice50_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_140...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_140.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_140.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 25       | BRATS_140       | 0.9535   | 0.9457   | 0.9030   | 0.9341
#     📸 Drawing Slice: 83
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_140_slice83_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_154...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_154.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_154.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 26       | BRATS_154       | 0.9662   | 0.9785   | 0.9380   | 0.9609
#     📸 Drawing Slice: 62
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_154_slice62_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_164...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_164.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_164.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 27       | BRATS_164       | 0.8395   | 0.9579   | 0.9325   | 0.9100
#     📸 Drawing Slice: 57
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_164_slice57_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_168...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_168.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_168.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 28       | BRATS_168       | 0.9451   | 0.9381   | 0.8806   | 0.9213
#     📸 Drawing Slice: 47
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_168_slice47_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_170...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_170.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_170.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 29       | BRATS_170       | 0.9492   | 0.9508   | 0.9021   | 0.9341
#     📸 Drawing Slice: 103
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_170_slice103_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_171...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_171.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_171.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 30       | BRATS_171       | 0.9132   | 0.8936   | 0.7665   | 0.8578
#     📸 Drawing Slice: 59
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS
nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 51       | BRATS_260       | 0.8795   | 0.8364   | 0.8253   | 0.8470
#     📸 Drawing Slice: 55
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_260_slice55_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_265...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_265.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_265.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 52       | BRATS_265       | 0.9420   | 0.9524   | 0.0000   | 0.6314
#     📸 Drawing Slice: 95
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_265_slice95_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_266...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_266.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_266.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 53       | BRATS_266       | 0.9469   | 0.8074   | 0.0000   | 0.5848
#     📸 Drawing Slice: 106
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_266_slice106_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_274...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_274.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_274.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 54       | BRATS_274       | 0.9176   | 0.8707   | 0.8737   | 0.8873
#     📸 Drawing Slice: 64
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_274_slice64_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_278...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_278.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_278.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 55       | BRATS_278       | 0.8929   | 0.3946   | 0.0000   | 0.4292
#     📸 Drawing Slice: 36
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_278_slice36_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_282...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_282.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_282.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 56       | BRATS_282       | 0.9645   | 0.7541   | 0.8395   | 0.8527
#     📸 Drawing Slice: 38
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_282_slice38_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_289...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_289.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_289.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 57       | BRATS_289       | 0.9670   | 0.8766   | 0.0000   | 0.6145
#     📸 Drawing Slice: 43
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_289_slice43_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_291...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_291.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_291.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 58       | BRATS_291       | 0.9633   | 0.8217   | 0.2959   | 0.6936
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_291_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_292...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_292.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_292.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 59       | BRATS_292       | 0.9522   | 0.9139   | 0.7825   | 0.8829
#     📸 Drawing Slice: 37
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_292_slice37_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_299...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_299.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_299.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 60       | BRATS_299       | 0.9666   | 0.9627   | 0.8311   | 0.9202
#     📸 Drawing Slice: 111
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_299_slice111_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_306...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_306.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_306.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 61       | BRATS_306       | 0.9374   | 0.7895   | 0.0000   | 0.5756
#     📸 Drawing Slice: 84
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_306_slice84_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_314...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_314.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_314.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 62       | BRATS_314       | 0.8446   | 0.8533   | 0.8955   | 0.8644
#     📸 Drawing Slice: 84
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_314_slice84_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_315...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_315.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_315.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 63       | BRATS_315       | 0.9724   | 0.9537   | 0.8542   | 0.9267
#     📸 Drawing Slice: 100
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_315_slice100_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_318...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_318.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_318.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 64       | BRATS_318       | 0.9653   | 0.9209   | 0.7264   | 0.8709
#     📸 Drawing Slice: 43
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_318_slice43_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_323...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_323.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_323.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 65       | BRATS_323       | 0.9256   | 0.9074   | 0.0004   | 0.6111
#     📸 Drawing Slice: 49
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_323_slice49_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_325...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_325.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_325.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 66       | BRATS_325       | 0.8812   | 0.8381   | 0.6073   | 0.7755
#     📸 Drawing Slice: 66
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_325_slice66_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_327...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_327.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_327.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 67       | BRATS_327       | 0.9705   | 0.8961   | 0.7384   | 0.8683
#     📸 Drawing Slice: 48
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_327_slice48_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_328...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_328.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_328.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 68       | BRATS_328       | 0.9514   | 0.8149   | 0.5733   | 0.7799
#     📸 Drawing Slice: 39
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_328_slice39_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_335...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_335.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_335.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 69       | BRATS_335       | 0.9146   | 0.8071   | 0.0000   | 0.5739
#     📸 Drawing Slice: 97
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_335_slice97_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_337...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_337.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_337.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 70       | BRATS_337       | 0.9765   | 0.9746   | 0.9337   | 0.9616
#     📸 Drawing Slice: 53
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_337_slice53_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_344...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_344.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_344.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 71       | BRATS_344       | 0.9386   | 0.8659   | 0.6742   | 0.8263
#     📸 Drawing Slice: 103
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_344_slice103_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_348...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_348.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_348.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 72       | BRATS_348       | 0.9789   | 0.9595   | 0.9084   | 0.9489
#     📸 Drawing Slice: 84
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_348_slice84_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_363...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_363.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_363.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 73       | BRATS_363       | 0.9731   | 0.9782   | 0.9563   | 0.9692
#     📸 Drawing Slice: 99
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_363_slice99_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_367...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_367.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_367.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 74       | BRATS_367       | 0.9651   | 0.9646   | 0.9436   | 0.9578
#     📸 Drawing Slice: 39
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_367_slice39_viz.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9301     | 0.9015     | 0.7646
# HD95 (mm)       | 3.2904     | 3.9499     | 34.0963
# ------------------------------------------------------------
# Overall Mean Dice: 0.8654
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/metrics_summary/metrics_summary_fold3.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ## 5. Fold 4

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode baseline --fold 4 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: BASELINE | FOLD: 4 ---
# 🔧 Initializing Engine | Mode: BASELINE...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 4: 73 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 73 cases (Filtered).
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_001...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_001.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_001.nii -> KHÔNG
# 100% 8/8 [00:05<00:00,  1.60it/s]
# 1        | BRATS_001       | 0.9202   | 0.9488   | 0.8945   | 0.9212
#     📸 Drawing Slice: 44
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_001_slice44_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_006...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_006.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_006.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 2        | BRATS_006       | 0.9313   | 0.9217   | 0.8151   | 0.8893
#     📸 Drawing Slice: 85
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_006_slice85_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_013...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_013.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_013.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 3        | BRATS_013       | 0.9048   | 0.9265   | 0.7165   | 0.8493
#     📸 Drawing Slice: 93
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_013_slice93_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_024...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_024.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_024.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 4        | BRATS_024       | 0.9093   | 0.8996   | 0.8700   | 0.8930
#     📸 Drawing Slice: 108
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_024_slice108_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_030...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_030.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_030.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 5        | BRATS_030       | 0.8405   | 0.8399   | 0.8185   | 0.8330
#     📸 Drawing Slice: 50
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_030_slice50_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_035...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_035.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_035.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 6        | BRATS_035       | 0.8842   | 0.8620   | 0.8142   | 0.8535
#     📸 Drawing Slice: 38
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_035_slice38_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_037...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_037.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_037.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 7        | BRATS_037       | 0.8842   | 0.9434   | 0.8519   | 0.8932
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_037_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_044...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_044.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_044.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 8        | BRATS_044       | 0.8322   | 0.7786   | 0.7964   | 0.8024
#     📸 Drawing Slice: 56
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_044_slice56_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_059...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_059.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_059.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 9        | BRATS_059       | 0.8286   | 0.8906   | 0.8648   | 0.8613
#     📸 Drawing Slice: 92
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_059_slice92_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_060...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_060.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_060.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.24it/s]
# 10       | BRATS_060       | 0.9285   | 0.9504   | 0.8432   | 0.9073
#     📸 Drawing Slice: 106
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_060_slice106_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_063...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_063.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_063.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 11       | BRATS_063       | 0.8968   | 0.8679   | 0.7637   | 0.8428
#     📸 Drawing Slice: 77
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_063_slice77_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_064...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_064.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_064.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.23it/s]
# 12       | BRATS_064       | 0.8541   | 0.9059   | 0.7666   | 0.8422
#     📸 Drawing Slice: 37
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_064_slice37_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_065...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_065.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_065.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 13       | BRATS_065       | 0.8368   | 0.9333   | 0.8776   | 0.8826
#     📸 Drawing Slice: 118
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_065_slice118_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_073...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_073.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_073.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 14       | BRATS_073       | 0.9230   | 0.9539   | 0.8499   | 0.9089
#     📸 Drawing Slice: 95
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_073_slice95_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_075...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_075.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_075.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 15       | BRATS_075       | 0.9537   | 0.9622   | 0.7962   | 0.9040
#     📸 Drawing Slice: 97
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_075_slice97_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_077...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_077.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_077.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 16       | BRATS_077       | 0.9330   | 0.9510   | 0.8863   | 0.9234
#     📸 Drawing Slice: 115
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_077_slice115_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_078...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_078.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_078.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 17       | BRATS_078       | 0.8599   | 0.9329   | 0.8203   | 0.8711
#     📸 Drawing Slice: 44
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_078_slice44_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_081...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_081.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_081.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 18       | BRATS_081       | 0.9351   | 0.9345   | 0.8208   | 0.8968
#     📸 Drawing Slice: 113
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_081_slice113_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_082...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_082.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_082.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 19       | BRATS_082       | 0.8220   | 0.8941   | 0.8042   | 0.8401
#     📸 Drawing Slice: 72
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_082_slice72_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_083...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_083.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_083.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 20       | BRATS_083       | 0.9408   | 0.9543   | 0.8825   | 0.9259
#     📸 Drawing Slice: 105
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_083_slice105_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_084...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_084.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_084.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 21       | BRATS_084       | 0.9375   | 0.9336   | 0.8334   | 0.9015
#     📸 Drawing Slice: 35
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_084_slice35_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_092...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_092.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_092.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 22       | BRATS_092       | 0.9444   | 0.9577   | 0.9361   | 0.9461
#     📸 Drawing Slice: 64
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_092_slice64_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_106...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_106.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_106.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.24it/s]
# 23       | BRATS_106       | 0.9468   | 0.9597   | 0.9222   | 0.9429
#     📸 Drawing Slice: 75
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_106_slice75_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_108...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_108.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_108.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 24       | BRATS_108       | 0.9398   | 0.9658   | 0.9554   | 0.9537
#     📸 Drawing Slice: 107
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_108_slice107_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_109...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_109.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_109.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 25       | BRATS_109       | 0.9509   | 0.9726   | 0.9482   | 0.9572
#     📸 Drawing Slice: 92
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_109_slice92_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_119...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_119.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_119.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 26       | BRATS_119       | 0.8701   | 0.9496   | 0.8893   | 0.9030
#     📸 Drawing Slice: 128
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_119_slice128_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_120...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_120.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_120.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 27       | BRATS_120       | 0.9803   | 0.9715   | 0.9039   | 0.9519
#     📸 Drawing Slice: 88
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_120_slice88_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_125...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_125.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_125.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 28       | BRATS_125       | 0.9734   | 0.9510   | 0.9469   | 0.9571
#     📸 Drawing Slice: 51
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_125_slice51_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_130...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_130.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_130.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 29       | BRATS_130       | 0.8873   | 0.9628   | 0.8872   | 0.9124
#     📸 Drawing Slice: 24
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_130_slice24_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_134...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_134.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_134.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 30       | BRATS_134       | 0.9090   | 0.9192   | 0.8110   | 0.8797
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_134_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_139...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_139.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_139.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 31       | BRATS_139       | 0.8914   | 0.9317   | 0.9031   | 0.9087
#     📸 Drawing Slice: 104
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_139_slice104_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_143...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_143.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_143.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 32       | BRATS_143       | 0.9354   | 0.9569   | 0.7771   | 0.8898
#     📸 Drawing Slice: 92
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_143_slice92_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_144...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_144.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_144.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 33       | BRATS_144       | 0.9391   | 0.9450   | 0.9417   | 0.9419
#     📸 Drawing Slice: 81
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_144_slice81_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_147...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_147.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_147.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 34       | BRATS_147       | 0.9110   | 0.7622   | 0.2046   | 0.6259
#     📸 Drawing Slice: 98
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_147_slice98_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_156...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_156.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_156.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.23it/s]
# 35       | BRATS_156       | 0.9546   | 0.9394   | 0.9585   | 0.9508
#     📸 Drawing Slice: 102
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_156_slice102_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_167...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_167.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_167.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 36       | BRATS_167       | 0.9281   | 0.9129   | 0.8571   | 0.8994
#     📸 Drawing Slice: 93
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_167_slice93_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_172...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_172.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_172.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 37       | BRATS_172       | 0.9509   | 0.9606   | 0.9472   | 0.9529
#     📸 Drawing Slice: 90
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_172_slice90_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_173...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_173.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_173.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 38       | BRATS_173       | 0.8998   | 0.9044   | 0.8730   | 0.8924
#     📸 Drawing Slice: 91
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_173_slice91_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_179...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_179.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_179.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 39       | BRATS_179       | 0.9535   | 0.9393   | 0.9080   | 0.9336
#     📸 Drawing Slice: 122
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_179_slice122_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_186...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_186.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_186.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 40       | BRATS_186       | 0.9255   | 0.9572   | 0.9407   | 0.9411
#     📸 Drawing Slice: 103
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_186_slice103_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_190...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_190.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_190.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 41       | BRATS_190       | 0.9264   | 0.8736   | 0.8697   | 0.8899
#     📸 Drawing Slice: 117
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_190_slice117_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_202...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_202.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_202.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 42       | BRATS_202       | 0.9586   | 0.9347   | 0.9123   | 0.9352
#     📸 Drawing Slice: 102
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_202_slice102_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_209...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_209.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_209.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 43       | BRATS_209       | 0.9416   | 0.9558   | 0.8797   | 0.9257
#     📸 Drawing Slice: 29
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_209_slice29_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_211...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_211.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_211.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 44       | BRATS_211       | 0.9337   | 0.9639   | 0.8997   | 0.9324
#     📸 Drawing Slice: 46
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_211_slice46_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_219...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_219.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_219.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 45       | BRATS_219       | 0.8949   | 0.9645   | 0.9249   | 0.9281
#     📸 Drawing Slice: 112
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_219_slice112_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_227...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_227.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_227.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 46       | BRATS_227       | 0.8892   | 0.8735   | 0.7960   | 0.8529
#     📸 Drawing Slice: 99
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_227_slice99_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_228...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_228.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_228.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 47       | BRATS_228       | 0.9096   | 0.9538   | 0.9270   | 0.9302
#     📸 Drawing Slice: 29
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_228_slice29_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_232...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_232.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_232.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 48       | BRATS_232       | 0.9287   | 0.8376   | 0.8038   | 0.8567
#     📸 Drawing Slice: 113
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_232_slice113_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_236...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_236.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_236.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 49       | BRATS_236       | 0.9446   | 0.8930   | 0.7789   | 0.8722
#     📸 Drawing Slice: 41
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_236_slice41_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_248...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_248.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_248.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 50       | BRATS_248       | 0.9413   | 0.9600   | 0.8969   | 0.9327
#     📸 Drawing Slice: 77
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_248_slice77_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_249...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_249.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_249.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 51       | BRATS_249       | 0.9046   | 0.9192   | 0.9079   | 0.9106
#     📸 Drawing Slice: 117
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_249_slice117_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_252...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_252.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_252.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 52       | BRATS_252       | 0.9678   | 0.9500   | 0.8903   | 0.9361
#     📸 Drawing Slice: 91
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_252_slice91_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_253...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_253.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_253.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 53       | BRATS_253       | 0.9591   | 0.9518   | 0.8217   | 0.9108
#     📸 Drawing Slice: 101
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_253_slice101_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_258...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_258.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_258.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 54       | BRATS_258       | 0.9535   | 0.9469   | 0.8815   | 0.9273
#     📸 Drawing Slice: 64
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_258_slice64_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_262...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_262.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_262.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 55       | BRATS_262       | 0.9103   | 0.7573   | 0.0000   | 0.5558
#     📸 Drawing Slice: 112
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_262_slice112_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_264...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_264.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_264.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 56       | BRATS_264       | 0.9032   | 0.8935   | 0.0000   | 0.5989
#     📸 Drawing Slice: 41
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_264_slice41_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_268...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_268.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_268.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 57       | BRATS_268       | 0.8629   | 0.8773   | 1.0000   | 0.9134
#     📸 Drawing Slice: 32
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_268_slice32_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_279...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_279.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_279.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 58       | BRATS_279       | 0.9627   | 0.9219   | 0.0000   | 0.6282
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_279_slice40_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_280...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_280.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_280.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 59       | BRATS_280       | 0.9671   | 0.4636   | 0.8341   | 0.7549
#     📸 Drawing Slice: 104
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_280_slice104_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_286...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_286.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_286.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 60       | BRATS_286       | 0.9089   | 0.7642   | 0.0000   | 0.5577
#     📸 Drawing Slice: 80
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_286_slice80_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_288...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_288.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_288.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 61       | BRATS_288       | 0.9362   | 0.8480   | 0.8885   | 0.8909
#     📸 Drawing Slice: 30
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_288_slice30_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_295...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_295.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_295.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 62       | BRATS_295       | 0.9279   | 0.8426   | 0.3645   | 0.7117
#     📸 Drawing Slice: 53
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_295_slice53_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_298...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_298.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_298.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 63       | BRATS_298       | 0.9141   | 0.7340   | 0.4904   | 0.7128
#     📸 Drawing Slice: 55
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_298_slice55_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_303...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_303.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_303.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 64       | BRATS_303       | 0.8519   | 0.6996   | 0.6585   | 0.7367
#     📸 Drawing Slice: 81
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_303_slice81_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_310...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_310.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_310.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 65       | BRATS_310       | 0.9530   | 0.9165   | 0.0000   | 0.6232
#     📸 Drawing Slice: 41
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_310_slice41_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_316...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_316.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_316.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 66       | BRATS_316       | 0.9256   | 0.7981   | 0.7743   | 0.8327
#     📸 Drawing Slice: 56
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_316_slice56_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_324...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_324.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_324.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 67       | BRATS_324       | 0.9314   | 0.7534   | 0.0000   | 0.5616
#     📸 Drawing Slice: 44
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_324_slice44_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_330...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_330.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_330.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 68       | BRATS_330       | 0.9562   | 0.9026   | 0.0000   | 0.6196
#     📸 Drawing Slice: 97
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_330_slice97_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_332...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_332.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_332.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 69       | BRATS_332       | 0.9549   | 0.6926   | 0.8722   | 0.8399
#     📸 Drawing Slice: 94
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_332_slice94_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_349...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_349.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_349.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.24it/s]
# 70       | BRATS_349       | 0.9567   | 0.9695   | 0.9250   | 0.9504
#     📸 Drawing Slice: 54
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_349_slice54_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_358...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_358.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_358.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.24it/s]
# 71       | BRATS_358       | 0.9561   | 0.9177   | 0.9433   | 0.9391
#     📸 Drawing Slice: 29
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_358_slice29_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_365...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_365.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_365.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 72       | BRATS_365       | 0.9671   | 0.9789   | 0.9504   | 0.9655
#     📸 Drawing Slice: 36
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_365_slice36_viz.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_366...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_366.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_366.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.24it/s]
# 73       | BRATS_366       | 0.9599   | 0.9494   | 0.9344   | 0.9479
#     📸 Drawing Slice: 92
#     ✅ Saved Snapshot: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/BRATS_366_slice92_viz.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9206     | 0.8995     | 0.7633
# HD95 (mm)       | 3.0094     | 3.1771     | 38.2500
# ------------------------------------------------------------
# Overall Mean Dice: 0.8612
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs__nnUNetPlans__3d_fullres/metrics_summary/metrics_summary_fold4.csv
#
# ✅ --- PIPELINE COMPLETED ---
