# %%
# Cài nnU-Net bản chuẩn từ PyPI (Nhanh và sạch)
# !pip install -q nnunetv2

# Cài thêm các thư viện bổ trợ nếu thiếu
# !pip install -q nibabel matplotlib medpy pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 4.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 66.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 71.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 87.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 6.0 MB/s eta 0:00:00
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Building wheel for acvl-utils (setup.py) ... done
#   Building wheel for batchgenerators (setup.py) ... done
#   Building wheel for batchgeneratorsv2 (pyproject.toml) ... done
#   Building wheel for dynamic-network-architectures (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for medpy (setup.py) ... done

# %% [markdown]
# # A. Set up

# %% [markdown]
# ## 1. Giải nén `nnUNet_raw` & `nnUNet_preprocessed`

# %%
import os
import zipfile
from tqdm import tqdm

RAW_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_raw/Dataset101_BraTS2020.zip"
PRE_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_preprocessed/Dataset101_BraTS2020.zip"

RAW_DIR = "/content"
PRE_DIR = "/content"

def unzip(zip_path, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as z:
        for f in tqdm(z.namelist()):
            z.extract(f, out_dir)

# %%
unzip(RAW_ZIP, RAW_DIR)
# Out:
# 100%|██████████| 1848/1848 [03:35<00:00,  8.57it/s]

# %%
# unzip(PRE_ZIP, PRE_DIR)

# %% [markdown]
# ## 2. Set biến môi trường nnU-Net v2

# %%
import os

os.environ["nnUNet_raw"] = "/content/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = "/content/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results"

print("nnUNet_raw:", os.environ["nnUNet_raw"])
print("nnUNet_preprocessed:", os.environ["nnUNet_preprocessed"])
print("nnUNet_results:", os.environ["nnUNet_results"])
# Out:
# nnUNet_raw: /content/nnUNet_raw
# nnUNet_preprocessed: /content/nnUNet_preprocessed
# nnUNet_results: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results

# %% [markdown]
# # B. ECE - 10 Bins - Test set

# %% [markdown]
# ## 1. EDL with engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode edl_250_fixed_split --bins 10 --eval_set test
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: EDL_250_FIXED_SPLIT | BINS: 10
# Đang gom dữ liệu Confidence: 100% 74/74 [06:30<00:00,  5.28s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ==================================================
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ==================================================
# Overall ECE Score: 1.5843 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_250epochs_FixedSplit__nnUNetPlans__3d_fullres/test/analysis_ece_results

# %% [markdown]
# ## 3. Baseline with engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode baseline_250_fixed_split --bins 10 --eval_set test
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: BASELINE_250_FIXED_SPLIT | BINS: 10
# Đang gom dữ liệu Confidence: 100% 74/74 [05:49<00:00,  4.72s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ==================================================
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ==================================================
# Overall ECE Score: 2.0486 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_250epochs_FixedSplit__nnUNetPlans__3d_fullres/test/analysis_ece_results
