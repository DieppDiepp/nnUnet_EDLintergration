# %%
# Cài nnU-Net bản chuẩn từ PyPI (Nhanh và sạch)
# !pip install -q nnunetv2

# Cài thêm các thư viện bổ trợ nếu thiếu
# !pip install -q nibabel matplotlib medpy pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.6/205.6 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 56.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 55.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 6.0 MB/s eta 0:00:00
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Building wheel for acvl-utils (pyproject.toml) ... done
#   Building wheel for batchgenerators (setup.py) ... done
#   Building wheel for dynamic-network-architectures (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for medpy (setup.py) ... done

# %% [markdown]
# # A. Set up

# %% [markdown]
# ## 1. Giải nén `nnUNet_raw` & `nnUNet_preprocessed`

# %%
import os
import zipfile
from tqdm import tqdm

RAW_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_raw/Dataset101_BraTS2020.zip"
PRE_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_preprocessed/Dataset101_BraTS2020.zip"

RAW_DIR = "/content"
PRE_DIR = "/content"

def unzip(zip_path, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as z:
        for f in tqdm(z.namelist()):
            z.extract(f, out_dir)

# %%
unzip(RAW_ZIP, RAW_DIR)
# Out:
# 100%|██████████| 1848/1848 [05:06<00:00,  6.04it/s]

# %%
# unzip(PRE_ZIP, PRE_DIR)

# %% [markdown]
# ## 2. Set biến môi trường nnU-Net v2

# %%
import os

os.environ["nnUNet_raw"] = "/content/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = "/content/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results"

print("nnUNet_raw:", os.environ["nnUNet_raw"])
print("nnUNet_preprocessed:", os.environ["nnUNet_preprocessed"])
print("nnUNet_results:", os.environ["nnUNet_results"])
# Out:
# nnUNet_raw: /content/nnUNet_raw
# nnUNet_preprocessed: /content/nnUNet_preprocessed
# nnUNet_results: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results

# %% [markdown]
# # B. ECE - 10 Bins - Test set

# %% [markdown]
# ## 1. EDL with engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode edl_50_fixed_split --bins 10 --eval_set test
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: EDL_50_FIXED_SPLIT | BINS: 10
# Đang gom dữ liệu Confidence: 100% 74/74 [03:29<00:00,  2.83s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ==================================================
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ==================================================
# Overall ECE Score: 1.0523 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/analysis_ece_results

# %% [markdown]
# ## 3. Baseline with engine

# %%
# !python /content/drive/MyDrive/NCKH/nnUnet/src/analysis/analysis_ece.py --mode baseline_50_fixed_split --bins 10 --eval_set test
# Out:
# 🚀 BẮT ĐẦU TÍNH ECE | CHẾ ĐỘ: BASELINE_50_FIXED_SPLIT | BINS: 10
# Đang gom dữ liệu Confidence: 100% 74/74 [02:46<00:00,  2.25s/it]
#
# ⏳ Đang tính toán ECE tổng thể (Gom toàn bộ pixel) với 10 bins...
#
# ==================================================
#        🏆 KẾT QUẢ EXPECTED CALIBRATION ERROR
# ==================================================
# Overall ECE Score: 1.7900 % (Càng nhỏ càng tốt)
# --------------------------------------------------
# ✅ Đã lưu kết quả tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/nnUNetTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/analysis_ece_results
