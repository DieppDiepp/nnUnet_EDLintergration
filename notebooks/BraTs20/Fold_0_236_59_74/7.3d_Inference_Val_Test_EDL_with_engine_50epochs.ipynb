# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cài nnU-Net bản chuẩn từ PyPI (Nhanh và sạch)
# !pip install -q nnunetv2

# Cài thêm các thư viện bổ trợ nếu thiếu
# !pip install -q nibabel matplotlib medpy pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.6/205.6 kB 18.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 51.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 104.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 108.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 128.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 10.4 MB/s eta 0:00:00
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Building wheel for acvl-utils (pyproject.toml) ... done
#   Building wheel for batchgenerators (setup.py) ... done
#   Building wheel for dynamic-network-architectures (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for medpy (setup.py) ... done

# %%
# !nvidia-smi
# Out:
# Thu Apr 16 10:10:05 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   41C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # A. Set up

# %% [markdown]
# ## 1. Giải nén `nnUNet_raw` & `nnUNet_preprocessed`

# %%
import os
import zipfile
from tqdm import tqdm

RAW_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_raw/Dataset101_BraTS2020.zip"
PRE_ZIP = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_preprocessed/Dataset101_BraTS2020.zip"

RAW_DIR = "/content"
PRE_DIR = "/content"

def unzip(zip_path, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as z:
        for f in tqdm(z.namelist()):
            z.extract(f, out_dir)

# %%
unzip(RAW_ZIP, RAW_DIR)
# Out:
# 100%|██████████| 1848/1848 [02:17<00:00, 13.43it/s]

# %%
unzip(PRE_ZIP, PRE_DIR)
# Out:
# 100%|██████████| 2590/2590 [06:50<00:00,  6.32it/s]

# %% [markdown]
# ## 2. Set biến môi trường nnU-Net v2

# %%
import os

os.environ["nnUNet_raw"] = "/content/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = "/content/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results"

print("nnUNet_raw:", os.environ["nnUNet_raw"])
print("nnUNet_preprocessed:", os.environ["nnUNet_preprocessed"])
print("nnUNet_results:", os.environ["nnUNet_results"])
# Out:
# nnUNet_raw: /content/nnUNet_raw
# nnUNet_preprocessed: /content/nnUNet_preprocessed
# nnUNet_results: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results

# %% [markdown]
# ## 3. Check split file

# %% [markdown]
# ### 3.1 Validation set

# %%
# !cp /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_preprocessed/Dataset101_BraTS2020/splits_final.json \
/content/nnUNet_preprocessed/Dataset101_BraTS2020/splits_final.json

# %%
import json

split_path = "/content/nnUNet_preprocessed/Dataset101_BraTS2020/splits_final.json"

with open(split_path) as f:
    splits = json.load(f)

print(f"Số folds: {len(splits)}")
print("Fold 0:", splits[0].keys())
print("Val size fold 0:", len(splits[0]["val"]))
# Out:
# Số folds: 5
# Fold 0: dict_keys(['train', 'val'])
# Val size fold 0: 59

# %% [markdown]
# ### 3.2 Test set

# %%
import json

split_path = "/content/drive/MyDrive/NCKH/nnUnet/data/experiments/fixed_test.json"

with open(split_path) as f:
    splits = json.load(f)

print(f"Số folds: {len(splits)}")

for fold_name, cases in splits.items():
    print(f"{fold_name}: {len(cases)} cases")
# Out:
# Số folds: 5
# fold_0: 74 cases
# fold_1: 74 cases
# fold_2: 74 cases
# fold_3: 74 cases
# fold_4: 73 cases

# %% [markdown]
# # B. Inference Uncertainty Map

# %%
# CHẾ ĐỘ 1: CHẠY MODEL EDL (UNCERTAINTY DECOMPOSITION)
# ------------------------------------------------------------------
# Script này sẽ thực hiện quy trình full:
# 1. Tự động "tiêm" (inject) file EDLTrainer.py vào thư viện nnU-Net hệ thống.
# 2. Load trọng số Model EDL (checkpoint_best.pth) từ đường dẫn config 'edl'.
# 3. Chạy Inference và tính toán toán học để tách Uncertainty thành:
#    - Aleatoric (Nhiễu dữ liệu)
#    - Epistemic (Mô hình chưa biết)
# 4. Lưu kết quả Segmentation + 3 bản đồ Uncertainty (.nii.gz).

# %%
# Đổi tên file cho đúng chuẩn (giải nén còn thừa .gz)
# !for f in /content/nnUNet_raw/Dataset101_BraTS2020/imagesTr/*.nii.gz; do mv "$f" "${f%.gz}"; done

# %% [markdown]
# ## 1. Validation Set

# %% [markdown]
# ### Fold 0

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode edl_50_fixed_split --fold 0 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: EDL_50_FIXED_SPLIT | FOLD: 0 ---
# 🔧 Initializing Engine | Mode: EDL...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 0: 59 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 59 cases (Filtered).
# 📁 Dữ liệu sẽ được lưu tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_006...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_006.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_006.nii -> KHÔNG
# 100% 8/8 [00:05<00:00,  1.46it/s]
# 1        | BRATS_006       | 0.9342   | 0.9276   | 0.8045   | 0.8888
# /content/drive/MyDrive/NCKH/nnUnet/src/visualizer.py:141: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.93])
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_006/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_006/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_006/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_007...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_007.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_007.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.17it/s]
# 2        | BRATS_007       | 0.9223   | 0.9252   | 0.8773   | 0.9083
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_007/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_007/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_007/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_010...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_010.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_010.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.16it/s]
# 3        | BRATS_010       | 0.8384   | 0.8971   | 0.8763   | 0.8706
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_010/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_010/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_010/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_031...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_031.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_031.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.15it/s]
# 4        | BRATS_031       | 0.9051   | 0.9162   | 0.8724   | 0.8979
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_031/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_031/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_031/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_034...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_034.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_034.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.30it/s]
# 5        | BRATS_034       | 0.9469   | 0.9431   | 0.8417   | 0.9106
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_034/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_034/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_034/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_035...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_035.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_035.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.14it/s]
# 6        | BRATS_035       | 0.8780   | 0.8640   | 0.7796   | 0.8405
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_035/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_035/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_035/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_044...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_044.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_044.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.14it/s]
# 7        | BRATS_044       | 0.8209   | 0.7435   | 0.7270   | 0.7638
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_044/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_044/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_044/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_047...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_047.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_047.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.13it/s]
# 8        | BRATS_047       | 0.8913   | 0.9357   | 0.8485   | 0.8918
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_047/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_047/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_047/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_060...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_060.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_060.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.29it/s]
# 9        | BRATS_060       | 0.9273   | 0.9501   | 0.8354   | 0.9043
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_060/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_060/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_060/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_063...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_063.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_063.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.13it/s]
# 10       | BRATS_063       | 0.9016   | 0.8663   | 0.7733   | 0.8471
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_063/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_063/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_063/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_064...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_064.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_064.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.28it/s]
# 11       | BRATS_064       | 0.8530   | 0.9075   | 0.7656   | 0.8420
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_064/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_064/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_064/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_076...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_076.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_076.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.13it/s]
# 12       | BRATS_076       | 0.8957   | 0.8234   | 0.7485   | 0.8225
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_076/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_076/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_076/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_079...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_079.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_079.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.12it/s]
# 13       | BRATS_079       | 0.7826   | 0.8761   | 0.6216   | 0.7601
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_079/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_079/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_079/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_080...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_080.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_080.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2
png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9108     | 0.8317     | 0.7371
# HD95 (mm)       | 4.6592     | 6.1052     | 35.9574
# ------------------------------------------------------------
# Overall Mean Dice: 0.8265
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/metrics_summary/metrics_summary_fold0.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ### Fold 1

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode edl_50_fixed_split --fold 1 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: EDL_50_FIXED_SPLIT | FOLD: 1 ---
# 🔧 Initializing Engine | Mode: EDL...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 1: 59 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 59 cases (Filtered).
# 📁 Dữ liệu sẽ được lưu tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_013...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_013.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_013.nii -> KHÔNG
# 100% 8/8 [00:05<00:00,  1.58it/s]
# 1        | BRATS_013       | 0.9041   | 0.9248   | 0.6945   | 0.8411
# /content/drive/MyDrive/NCKH/nnUnet/src/visualizer.py:141: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.93])
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_013/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_013/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_013/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_018...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_018.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_018.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 2        | BRATS_018       | 0.8280   | 0.6899   | 0.6612   | 0.7264
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_018/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_018/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_018/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_022...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_022.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_022.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 3        | BRATS_022       | 0.9490   | 0.9436   | 0.8768   | 0.9231
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_022/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_022/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_022/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_024...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_024.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_024.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 4        | BRATS_024       | 0.9047   | 0.8958   | 0.8695   | 0.8900
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_024/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_024/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_024/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_025...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_025.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_025.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 5        | BRATS_025       | 0.9260   | 0.9662   | 0.8934   | 0.9285
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_025/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_025/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_025/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_026...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_026.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_026.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 6        | BRATS_026       | 0.9480   | 0.8551   | 0.7175   | 0.8402
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_026/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_026/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_026/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_054...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_054.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_054.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.23it/s]
# 7        | BRATS_054       | 0.9083   | 0.9446   | 0.9002   | 0.9177
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_054/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_054/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_054/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_055...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_055.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_055.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 8        | BRATS_055       | 0.9498   | 0.9492   | 0.8416   | 0.9135
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_055/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_055/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_055/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_075...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_075.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_075.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 9        | BRATS_075       | 0.9604   | 0.9602   | 0.7692   | 0.8966
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_075/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_075/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_075/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_077...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_077.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_077.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 10       | BRATS_077       | 0.9351   | 0.9460   | 0.8743   | 0.9185
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_077/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_077/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_077/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_083...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_083.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_083.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 11       | BRATS_083       | 0.9403   | 0.9499   | 0.8743   | 0.9215
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_083/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_083/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_083/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_087...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_087.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_087.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 12       | BRATS_087       | 0.8026   | 0.7051   | 0.3969   | 0.6349
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_087/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_087/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_087/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_090...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_090.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_090.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 13       | BRATS_090       | 0.9385   | 0.9695   | 0.9179   | 0.9420
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_090/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_090/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_090/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_091...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_091.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_091.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 14       | BRATS_091       | 0.9089   | 0.9697   | 0.9540   | 0.9442
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_091/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_091/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_091/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_092...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_092.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_092.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 15       | BRATS_092       | 0.9530   | 0.9625   | 0.9408   | 0.9521
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_092/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_092/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_092/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_095...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_095.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_095.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 16       | BRATS_095       | 0.9748   | 0.9282   | 0.8484   | 0.9171
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_095/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_095/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_095/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_099...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_099.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_099.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 17       | BRATS_099       | 0.7719   | 0.7513   | 0.7713   | 0.7648
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_099/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_099/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_099/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_102...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_102.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_102.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 18       | BRATS_102       | 0.9192   | 0.9165   | 0.8258   | 0.8872
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_102/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_102/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_102/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_106...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS
Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_236/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_236/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_238...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_238.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_238.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 43       | BRATS_238       | 0.9571   | 0.9561   | 0.7752   | 0.8961
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_238/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_238/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_238/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_244...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_244.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_244.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 44       | BRATS_244       | 0.9592   | 0.9365   | 0.7950   | 0.8969
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_244/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_244/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_244/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_247...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_247.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_247.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 45       | BRATS_247       | 0.9195   | 0.9549   | 0.9277   | 0.9340
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_247/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_247/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_247/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_260...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_260.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_260.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 46       | BRATS_260       | 0.8958   | 0.8571   | 0.8711   | 0.8747
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_260/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_260/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_260/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_279...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_279.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_279.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 47       | BRATS_279       | 0.9587   | 0.9369   | 0.0000   | 0.6318
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_279/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_279/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_279/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_283...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_283.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_283.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 48       | BRATS_283       | 0.9531   | 0.7716   | 0.8341   | 0.8529
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_283/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_283/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_283/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_286...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_286.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_286.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 49       | BRATS_286       | 0.9104   | 0.8258   | 0.0000   | 0.5788
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_286/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_286/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_286/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_306...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_306.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_306.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 50       | BRATS_306       | 0.9237   | 0.7826   | 0.0000   | 0.5688
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_306/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_306/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_306/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_311...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_311.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_311.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 51       | BRATS_311       | 0.8802   | 0.6154   | 0.8711   | 0.7889
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_311/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_311/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_311/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_315...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_315.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_315.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 52       | BRATS_315       | 0.9834   | 0.9325   | 0.6788   | 0.8649
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_315/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_315/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_315/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_319...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_319.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_319.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 53       | BRATS_319       | 0.9582   | 0.9257   | 0.0000   | 0.6280
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_319/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_319/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_319/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_337...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_337.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_337.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 54       | BRATS_337       | 0.9800   | 0.9768   | 0.9328   | 0.9632
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_337/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_337/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_337/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_349...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_349.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_349.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.24it/s]
# 55       | BRATS_349       | 0.9632   | 0.9674   | 0.9186   | 0.9497
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_349/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_349/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_349/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_351...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_351.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_351.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 56       | BRATS_351       | 0.9681   | 0.9801   | 0.9667   | 0.9716
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_351/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_351/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_351/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_356...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_356.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_356.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 57       | BRATS_356       | 0.9189   | 0.9486   | 0.9113   | 0.9263
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_356/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_356/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_356/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_361...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_361.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_361.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 58       | BRATS_361       | 0.9689   | 0.0000   | 0.0000   | 0.3230
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_361/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_361/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_361/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_366...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_366.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_366.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.23it/s]
# 59       | BRATS_366       | 0.9636   | 0.9543   | 0.9412   | 0.9530
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_366/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_366/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_366/Axial_75pct_Bottom.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9331     | 0.8862     | 0.7743
# HD95 (mm)       | 2.5853     | 3.8095     | 28.4508
# ------------------------------------------------------------
# Overall Mean Dice: 0.8645
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/metrics_summary/metrics_summary_fold1.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ### Fold 2

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode edl_50_fixed_split --fold 2 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: EDL_50_FIXED_SPLIT | FOLD: 2 ---
# 🔧 Initializing Engine | Mode: EDL...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 2: 59 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 59 cases (Filtered).
# 📁 Dữ liệu sẽ được lưu tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_001...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_001.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_001.nii -> KHÔNG
# 100% 8/8 [00:05<00:00,  1.59it/s]
# 1        | BRATS_001       | 0.9239   | 0.9473   | 0.8851   | 0.9188
# /content/drive/MyDrive/NCKH/nnUnet/src/visualizer.py:144: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 
nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 48       | BRATS_318       | 0.9647   | 0.9382   | 0.4835   | 0.7955
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_318/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_318/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_318/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_322...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_322.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_322.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 49       | BRATS_322       | 0.9715   | 0.9147   | 0.4056   | 0.7639
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_322/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_322/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_322/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_325...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_325.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_325.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 50       | BRATS_325       | 0.8627   | 0.7859   | 0.0000   | 0.5495
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_325/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_325/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_325/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_327...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_327.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_327.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 51       | BRATS_327       | 0.9691   | 0.9109   | 0.6858   | 0.8553
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_327/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_327/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_327/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_335...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_335.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_335.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 52       | BRATS_335       | 0.9221   | 0.8337   | 0.0000   | 0.5853
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_335/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_335/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_335/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_336...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_336.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_336.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 53       | BRATS_336       | 0.9811   | 0.9817   | 0.9469   | 0.9699
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_336/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_336/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_336/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_338...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_338.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_338.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.23it/s]
# 54       | BRATS_338       | 0.9567   | 0.9755   | 0.9534   | 0.9619
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_338/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_338/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_338/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_343...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_343.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_343.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 55       | BRATS_343       | 0.9451   | 0.9488   | 0.9043   | 0.9327
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_343/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_343/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_343/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_344...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_344.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_344.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.23it/s]
# 56       | BRATS_344       | 0.9438   | 0.8631   | 0.6868   | 0.8313
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_344/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_344/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_344/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_346...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_346.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_346.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 57       | BRATS_346       | 0.9728   | 0.9813   | 0.9304   | 0.9615
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_346/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_346/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_346/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_362...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_362.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_362.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 58       | BRATS_362       | 0.9656   | 0.9580   | 0.9076   | 0.9437
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_362/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_362/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_362/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_364...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_364.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_364.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 59       | BRATS_364       | 0.9511   | 0.9423   | 0.8950   | 0.9294
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_364/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_364/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_364/Axial_75pct_Bottom.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9276     | 0.9084     | 0.7928
# HD95 (mm)       | 3.0241     | 3.1603     | 22.8181
# ------------------------------------------------------------
# Overall Mean Dice: 0.8763
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/metrics_summary/metrics_summary_fold2.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ### Fold 3

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode edl_50_fixed_split --fold 3 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: EDL_50_FIXED_SPLIT | FOLD: 3 ---
# 🔧 Initializing Engine | Mode: EDL...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 3: 59 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 59 cases (Filtered).
# 📁 Dữ liệu sẽ được lưu tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_005...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_005.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_005.nii -> KHÔNG
# 100% 8/8 [00:05<00:00,  1.59it/s]
# 1        | BRATS_005       | 0.8395   | 0.9246   | 0.8218   | 0.8620
# /content/drive/MyDrive/NCKH/nnUnet/src/visualizer.py:144: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.93])
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_005/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_005/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_005/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_009...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_009.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_009.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 2        | BRATS_009       | 0.9102   | 0.8695   | 0.7931   | 0.8576
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_009/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_009/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_009/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_014...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_014.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_014.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 3        | BRATS_014       | 0.9199   | 0.9105   | 0.8267   | 0.8857
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_014/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_014/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_014/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_017...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_017.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_017.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 4        | BRATS_017       | 0.9321   | 0.8829   | 0.8213   | 0.8788
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_017/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_017/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_017/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_033...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_033.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_033.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 5        | BRATS_033       | 0.9547   | 0.9594   | 0.8974   | 0.9372
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_033/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_033/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_033/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_038...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_038.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_038.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 6        | BRATS_038       | 0.9079   | 0.8445   | 0.7828   | 0.8450
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS
nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_340.nii -> KHÔNG
# 100% 12/12 [00:05<00:00,  2.02it/s]
# 54       | BRATS_340       | 0.9740   | 0.9733   | 0.9573   | 0.9682
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_340/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_340/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_340/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_347...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_347.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_347.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 55       | BRATS_347       | 0.9779   | 0.9772   | 0.9607   | 0.9719
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_347/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_347/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_347/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_352...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_352.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_352.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 56       | BRATS_352       | 0.9381   | 0.9346   | 0.9273   | 0.9333
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_352/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_352/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_352/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_358...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_358.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_358.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.23it/s]
# 57       | BRATS_358       | 0.9645   | 0.9322   | 0.9528   | 0.9498
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_358/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_358/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_358/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_359...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_359.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_359.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 58       | BRATS_359       | 0.9748   | 0.9765   | 0.9430   | 0.9648
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_359/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_359/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_359/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_365...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_365.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_365.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 59       | BRATS_365       | 0.9679   | 0.9802   | 0.9526   | 0.9669
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_365/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_365/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_365/Axial_75pct_Bottom.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9285     | 0.8943     | 0.7038
# HD95 (mm)       | 2.7681     | 3.2109     | 42.7982
# ------------------------------------------------------------
# Overall Mean Dice: 0.8422
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/metrics_summary/metrics_summary_fold3.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ### Fold 4

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode edl_50_fixed_split --fold 4 --run_mode validation_split
# Out:
# 🏁 --- STARTING PIPELINE | MODE: EDL_50_FIXED_SPLIT | FOLD: 4 ---
# 🔧 Initializing Engine | Mode: EDL...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 4: 59 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 59 cases (Filtered).
# 📁 Dữ liệu sẽ được lưu tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_002...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_002.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_002.nii -> KHÔNG
# 100% 8/8 [00:05<00:00,  1.58it/s]
# 1        | BRATS_002       | 0.9143   | 0.9557   | 0.8516   | 0.9072
# /content/drive/MyDrive/NCKH/nnUnet/src/visualizer.py:144: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.93])
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_002/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_002/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_002/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_004...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_004.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_004.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 2        | BRATS_004       | 0.9526   | 0.9194   | 0.8762   | 0.9161
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_004/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_004/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_004/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_008...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_008.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_008.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 3        | BRATS_008       | 0.8451   | 0.8433   | 0.8308   | 0.8397
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_008/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_008/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_008/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_016...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_016.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_016.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 4        | BRATS_016       | 0.9294   | 0.8817   | 0.7074   | 0.8395
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_016/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_016/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_016/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_027...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_027.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_027.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 5        | BRATS_027       | 0.8166   | 0.9323   | 0.8574   | 0.8688
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_027/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_027/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_027/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_030...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_030.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_030.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 6        | BRATS_030       | 0.8506   | 0.8279   | 0.7902   | 0.8229
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_030/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_030/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_030/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_048...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_048.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_048.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 7        | BRATS_048       | 0.6659   | 0.9060   | 0.7863   | 0.7861
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_048/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_048/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_048/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_066...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_066.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_066.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 8        | BRATS_066       | 0.9435   | 0.9214   | 0.8143   | 0.8931
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_066/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_066/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_066/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_067...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_067.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_067.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 9        | BRATS_067       | 0.9504   | 0.9576   | 0.8932   | 0.9337
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_067/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_067/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_067/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_068...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_068.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_068.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 10       | BRATS_068       | 0.9381   | 0.9108   | 0.8406   | 0.8965
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_068/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_068/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_068/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_071...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_071.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_071.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 11       | BRATS_071       | 0.9169   | 0.7483   | 0.8284   | 0.8312
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_071/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_071/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_071/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_072...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_072.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_072.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
#
Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/BRATS_369/Axial_75pct_Bottom.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9198     | 0.8841     | 0.7647
# HD95 (mm)       | 3.5189     | 4.0226     | 34.0504
# ------------------------------------------------------------
# Overall Mean Dice: 0.8562
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/val/metrics_summary/metrics_summary_fold4.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ## 2. Test set - fold test 0

# %%
# !python "/content/drive/MyDrive/NCKH/nnUnet/src/main.py" --mode edl_50_fixed_split --fold 2 --test_fold 0 --run_mode fixed_test
# Out:
# 🏁 --- STARTING PIPELINE | MODE: EDL_50_FIXED_SPLIT | FOLD: 2 ---
# 🔧 Initializing Engine | Mode: EDL...
# 🚀 Initializing nnU-Net Predictor...
#    -> Cấu hình: Lật ảnh=True | Bước trượt=0.5
# 📂 Model loaded from: /content/drive/MyDrive/NCKH/nnUnet/data/nnUNet_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Test (fold_0): 74 ca.
# ⚙️ Mode: FIXED TEST | Model (Weights): Fold 2 | Data: Test Fold 0 -> 74 cases.
# 📁 Dữ liệu sẽ được lưu tại: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 🔍 DEBUG: Đang tìm GT cho BRATS_011...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_011.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_011.nii -> KHÔNG
# 100% 8/8 [00:04<00:00,  1.60it/s]
# 1        | BRATS_011       | 0.9278   | 0.9139   | 0.7531   | 0.8649
# /content/drive/MyDrive/NCKH/nnUnet/src/visualizer.py:144: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.93])
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_011/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_011/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_011/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_012...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_012.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_012.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 2        | BRATS_012       | 0.8435   | 0.9286   | 0.8461   | 0.8727
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_012/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_012/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_012/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_019...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_019.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_019.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 3        | BRATS_019       | 0.9004   | 0.9200   | 0.7843   | 0.8683
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_019/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_019/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_019/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_020...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_020.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_020.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.10it/s]
# 4        | BRATS_020       | 0.9036   | 0.8569   | 0.6937   | 0.8181
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_020/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_020/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_020/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_021...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_021.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_021.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 5        | BRATS_021       | 0.8011   | 0.9049   | 0.6815   | 0.7958
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_021/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_021/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_021/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_023...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_023.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_023.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.25it/s]
# 6        | BRATS_023       | 0.8999   | 0.9519   | 0.8640   | 0.9053
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_023/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_023/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_023/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_028...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_028.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_028.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 7        | BRATS_028       | 0.8809   | 0.8531   | 0.6472   | 0.7937
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_028/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_028/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_028/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_029...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_029.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_029.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.09it/s]
# 8        | BRATS_029       | 0.9359   | 0.9438   | 0.8841   | 0.9213
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_029/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_029/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_029/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_032...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_032.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_032.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 9        | BRATS_032       | 0.9112   | 0.8976   | 0.7879   | 0.8656
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_032/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_032/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_032/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_036...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_036.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_036.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 10       | BRATS_036       | 0.8794   | 0.8808   | 0.8386   | 0.8662
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_036/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_036/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_036/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_039...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_039.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_039.nii -> KHÔNG
# 100% 4/4 [00:01<00:00,  2.24it/s]
# 11       | BRATS_039       | 0.9281   | 0.9380   | 0.8815   | 0.9159
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_039/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_039/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_039/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_041...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_041.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_041.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
# 12       | BRATS_041       | 0.9468   | 0.9008   | 0.7571   | 0.8682
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_041/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_041/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_041/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_042...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_042.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_042.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.08it/s]
#
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_230/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_230/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_230/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_240...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_240.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_240.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 60       | BRATS_240       | 0.9056   | 0.7219   | 0.6084   | 0.7453
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_240/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_240/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_240/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_245...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_245.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_245.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 61       | BRATS_245       | 0.9368   | 0.9020   | 0.8529   | 0.8973
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_245/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_245/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_245/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_251...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_251.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_251.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 62       | BRATS_251       | 0.9565   | 0.9491   | 0.9392   | 0.9483
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_251/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_251/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_251/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_259...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_259.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_259.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 63       | BRATS_259       | 0.9668   | 0.2831   | 0.8315   | 0.6938
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_259/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_259/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_259/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_284...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_284.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_284.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 64       | BRATS_284       | 0.9323   | 0.8786   | 0.5516   | 0.7875
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_284/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_284/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_284/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_287...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_287.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_287.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 65       | BRATS_287       | 0.9708   | 0.9232   | 0.9249   | 0.9396
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_287/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_287/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_287/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_297...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_297.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_297.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 66       | BRATS_297       | 0.6220   | 0.7112   | 1.0000   | 0.7777
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_297/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_297/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_297/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_302...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_302.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_302.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 67       | BRATS_302       | 0.8815   | 0.8729   | 0.5828   | 0.7791
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_302/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_302/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_302/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_305...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_305.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_305.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 68       | BRATS_305       | 0.9410   | 0.8584   | 0.0000   | 0.5998
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_305/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_305/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_305/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_329...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_329.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_329.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 69       | BRATS_329       | 0.9140   | 0.7914   | 0.0000   | 0.5685
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_329/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_329/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_329/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_331...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_331.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_331.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 70       | BRATS_331       | 0.8420   | 0.4895   | 0.7768   | 0.7028
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_331/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_331/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_331/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_342...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_342.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_342.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 71       | BRATS_342       | 0.9241   | 0.9376   | 0.8837   | 0.9151
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_342/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_342/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_342/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_353...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_353.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_353.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.06it/s]
# 72       | BRATS_353       | 0.9674   | 0.9605   | 0.9173   | 0.9484
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_353/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_353/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_353/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_360...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_360.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_360.nii -> KHÔNG
# 100% 2/2 [00:00<00:00,  2.64it/s]
# 73       | BRATS_360       | 0.8743   | 0.9626   | 0.9366   | 0.9245
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_360/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_360/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_360/Axial_75pct_Bottom.png
# 🔍 DEBUG: Đang tìm GT cho BRATS_368...
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_368.nii.gz -> CÓ
#    - Thử: /content/nnUNet_raw/Dataset101_BraTS2020/labelsTr/BRATS_368.nii -> KHÔNG
# 100% 8/8 [00:03<00:00,  2.07it/s]
# 74       | BRATS_368       | 0.9568   | 0.9552   | 0.9407   | 0.9509
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_368/Axial_50pct_Center.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_368/Axial_25pct_Top.png
#     ✅ Saved: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/BRATS_368/Axial_75pct_Bottom.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9158     | 0.8826     | 0.8239
# HD95 (mm)       | 4.8795     | 3.8635     | 12.7609
# ------------------------------------------------------------
# Overall Mean Dice: 0.8741
# ✅ Report saved to: /content/drive/MyDrive/NCKH/nnUnet/inference_results/Dataset101_BraTS2020/EDLTrainer_50epochs_FixedSplit__nnUNetPlans__3d_fullres/test/metrics_summary/metrics_summary_fold2.csv
#
# ✅ --- PIPELINE COMPLETED ---

# %% [markdown]
# ##
