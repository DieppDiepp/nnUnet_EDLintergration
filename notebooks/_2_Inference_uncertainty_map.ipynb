# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cài nnU-Net bản chuẩn từ PyPI (Nhanh và sạch)
# !pip install nnunetv2

# Cài thêm các thư viện bổ trợ nếu thiếu
# !pip install nibabel matplotlib medpy pandas
# Out:
# Collecting nnunetv2
#   Downloading nnunetv2-2.6.2.tar.gz (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 kB 9.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.9.0+cu126)
# Collecting acvl-utils<0.3,>=0.2.3 (from nnunetv2)
#   Downloading acvl_utils-0.2.5.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dynamic-network-architectures<0.5,>=0.4.1 (from nnunetv2)
#   Downloading dynamic_network_architectures-0.4.2.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (1.16.3)
# Collecting batchgenerators>=0.25.1 (from nnunetv2)
#   Downloading batchgenerators-0.25.1.tar.gz (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (1.6.1)
# Requirement already satisfied: scikit-image>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.25.2)
# Collecting SimpleITK>=2.2.1 (from nnunetv2)
#   Downloading simpleitk-2.5.3-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.21)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2025.10.16)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.32.4)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (5.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.13.2)
# Collecting imagecodecs (from nnunetv2)
#   Downloading imagecodecs-2025.11.11-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting yacs (from nnunetv2)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Collecting batchgeneratorsv2>=0.3.0 (from nnunetv2)
#   Downloading batchgeneratorsv2-0.3.0.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.8.1)
# Requirement already satisfied: blosc2>=3.0.0b1 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (3.11.1)
# Collecting connected-components-3d (from acvl-utils<0.3,>=0.2.3->nnunetv2)
#   Downloading connected_components_3d-3.26.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (32 kB)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25.1->nnunetv2) (11.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25.1->nnunetv2) (1.0.0)
# Collecting unittest2 (from batchgenerators>=0.25.1->nnunetv2)
#   Downloading unittest2-1.1.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25.1->nnunetv2) (3.6.0)
# Collecting fft-conv-pytorch (from batchgeneratorsv2>=0.3.0->nnunetv2)
#   Downloading fft_conv_pytorch-1.2.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (1.10.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (1.1.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (4.5.0)
# Requirement already satisfied: numexpr>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (2.14.1)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (9.0.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (1.0.22)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19.3->nnunetv2) (3.6)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19.3->nnunetv2) (2.37.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19.3->nnunetv2) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19.3->nnunetv2) (0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->nnunetv2) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->nnunetv2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->nnunetv2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->nnunetv2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->nnunetv2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->nnunetv2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->nnunetv2) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->nnunetv2) (1.5.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from yacs->nnunetv2) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->nnunetv2) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.2->nnunetv2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.2->nnunetv2) (3.0.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm->dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (0.24.0+cu126)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (0.7.0)
# Collecting argparse (from unittest2->batchgenerators>=0.25.1->nnunetv2)
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting traceback2 (from unittest2->batchgenerators>=0.25.1->nnunetv2)
#   Downloading traceback2-1.4.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (1.2.0)
# Collecting linecache2 (from traceback2->unittest2->batchgenerators>=0.25.1->nnunetv2)
#   Downloading linecache2-1.0.0-py2.py3-none-any.whl.metadata (1000 bytes)
# Downloading simpleitk-2.5.3-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (52.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 24.0 MB/s eta 0:00:00
# Downloading imagecodecs-2025.11.11-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 99.1 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading connected_components_3d-3.26.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 111.8 MB/s eta 0:00:00
# Downloading fft_conv_pytorch-1.2.0-py3-none-any.whl (6.8 kB)
# Downloading unittest2-1.1.0-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 10.4 MB/s eta 0:00:00
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Downloading traceback2-1.4.0-py2.py3-none-any.whl (16 kB)
# Downloading linecache2-1.0.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: nnunetv2, acvl-utils, batchgenerators, batchgeneratorsv2, dynamic-network-architectures
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Created wheel for nnunetv2: filename=nnunetv2-2.6.2-py3-none-any.whl size=285890 sha256=f9e538c3b84633e288667ce959d3eee86133447982a7a309e16a1993875c9205
#   Stored in directory: /root/.cache/pip/wheels/35/48/6e/7bb3c448ce63cb43086410d2328bbe7c991c03e67ccffa28dc
#   Building wheel for acvl-utils (setup.py) ... done
#   Created wheel for acvl-utils: filename=acvl_utils-0.2.5-py3-none-any.whl size=27213 sha256=ba4b14b362451b81741f31f63e1ca64580c7d15af76659802fdbb167ab5e2f93
#   Stored in directory: /root/.cache/pip/wheels/70/c4/16/bae888b32a033f634d91a14256a8f8c8ec97db4e4dad8f0216
#   Building wheel for batchgenerators (setup.py) ... done
#   Created wheel for batchgenerators: filename=batchgenerators-0.25.1-py3-none-any.whl size=93088 sha256=0d2e0fb01175c0e428c07b2c75a4622f8f054d6bf2ba07bb3be3a0787d916798
#   Stored in directory: /root/.cache/pip/wheels/28/21/2b/7b25080f9f5847e6c3162b89d859d7cec9f3093158e56bd008
#   Building wheel for batchgeneratorsv2 (pyproject.toml) ... done
#   Created wheel for batchgeneratorsv2: filename=batchgeneratorsv2-0.3.0-py3-none-any.whl size=65215 sha256=ede169b2cc5df7f5fca7062618009ccd6b356e115f11f0ba710e525f007d3724
#   Stored in directory: /root/.cache/pip/wheels/9d/99/a0/1224a58f286be9fedbdb256d41e782a63b5ecab743e92ed302
#   Building wheel for dynamic-network-architectures (setup.py) ... done
#   Created wheel for dynamic-network-architectures: filename=dynamic_network_architectures-0.4.2-py3-none-any.whl size=39025 sha256=05c46feeeb0f67ed3db7826cae2d7b8480bcb71619691c2afa5e5ac873885965
#   Stored in directory: /root/.cache/pip/wheels/c2/a8/c5/241ab34db40b3a6f498d2794411cc08a6309fefdc0d6e3d9f3
# Successfully built nnunetv2 acvl-utils batchgenerators batchgeneratorsv2 dynamic-network-architectures
# Installing collected packages: SimpleITK, linecache2, argparse, yacs, traceback2, imagecodecs, connected-components-3d, unittest2, batchgenerators, fft-conv-pytorch, acvl-utils, batchgeneratorsv2, dynamic-network-architectures, nnunetv2
# Successfully installed SimpleITK-2.5.3 acvl-utils-0.2.5 argparse-1.4.0 batchgenerators-0.25.1 batchgeneratorsv2-0.3.0 connected-components-3d-3.26.1 dynamic-network-architectures-0.4.2 fft-conv-pytorch-1.2.0 imagecodecs-2025.11.11 linecache2-1.0.0 nnunetv2-2.6.2 traceback2-1.4.0 unittest2-1.1.0 yacs-0.1.8
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (5.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Collecting medpy
#   Downloading medpy-0.5.2.tar.gz (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from nibabel) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from nibabel) (25.0)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.12/dist-packages (from medpy) (1.16.3)
# Requirement already satisfied: SimpleITK>=2.1 in /usr/local/lib/python3.12/dist-packages (from medpy) (2.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.5.2-py3-none-any.whl size=224710 sha256=8e8023b9b0bc915fe73f860e6fb25ee27f8fdb5f0577457699d6880e0fcfda74
#   Stored in directory: /root/.cache/pip/wheels/89/5a/f8/b3def53b9c2133d2f8698ea2173bb5df63bd8e761ce8e9aec9
# Successfully built medpy
# Installing collected packages: medpy
# Successfully installed medpy-0.5.2

# %% [markdown]
# ## 1. Giải nén foler input

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# ### a. Giải nén `nnUNet_preprocessed` vào thư mục content của Colab

# %%
import os
import zipfile
from tqdm import tqdm
import shutil

# %%
# GIẢI NÉN DỮ LIỆU PREPROCESSED
# ----------------------------------------------------------------------

os.environ['nnUNet_raw'] = "/content/nnUNet_raw"
os.environ['nnUNet_preprocessed'] = "/content/nnUNet_preprocessed"
os.environ['nnUNet_results'] = "/content/drive/MyDrive/XUM_project/nnUNet_results"

# !mkdir -p $nnUNet_raw
# !mkdir -p $nnUNet_preprocessed

zip_path_drive = "/content/drive/MyDrive/XUM_project/nnUNET_preprocessed.zip"
zip_local = "/content/nnUNET_preprocessed.zip"
extract_root = "/content/nnUNet_preprocessed"

print("📦 Copy file từ Drive…")
# !cp "$zip_path_drive" "$zip_local"

print("💨 Copy xong. Bắt đầu giải nén…")

with zipfile.ZipFile(zip_local, 'r') as zip_ref:
    # Detect folder root name inside zip (vd: nnUNET_preprocessed/)
    root_name = zip_ref.namelist()[0].split('/')[0]

    file_list = zip_ref.infolist()
    total_files = len(file_list)

    print(f"🔧 Phát hiện folder root trong ZIP: {root_name}")
    print("🔧 Đang giải nén, loại bỏ lớp folder đầu tiên…")

    for file in tqdm(file_list, total=total_files, desc="🔄 Unzipping"):
        file_path = file.filename

        # Bỏ lớp folder đầu tiên
        fixed_path = file_path.replace(root_name + "/", "", 1)

        if fixed_path.strip() == "":
            continue

        # Chỉ định nơi lưu đúng
        target_path = os.path.join(extract_root, fixed_path)

        # Tạo thư mục nếu cần
        if file.is_dir():
            os.makedirs(target_path, exist_ok=True)
        else:
            os.makedirs(os.path.dirname(target_path), exist_ok=True)
            with zip_ref.open(file) as source, open(target_path, "wb") as target:
                target.write(source.read())

os.remove(zip_local)

print("🎉 GIẢI NÉN XONG VÀ ĐÃ TỰ ĐỘNG FIX FOLDER DOUBLE-LAYER! 😎🔥")
# Out:
# 📦 Copy file từ Drive…
# 💨 Copy xong. Bắt đầu giải nén…
# 🔧 Phát hiện folder root trong ZIP: nnUNET_preprocessed
# 🔧 Đang giải nén, loại bỏ lớp folder đầu tiên…
# 🔄 Unzipping: 100%|██████████| 2585/2585 [02:45<00:00, 15.62it/s]
# 🎉 GIẢI NÉN XONG VÀ ĐÃ TỰ ĐỘNG FIX FOLDER DOUBLE-LAYER! 😎🔥

# %% [markdown]
# ### b. Giải nén `nnUNet_raw` vào thư mục content của Colab

# %%
# GIẢI NÉN DỮ LIỆU RAW (QUAN TRỌNG CHO INFERENCE)
# ----------------------------------------------------------------------

# 1. Thiết lập đường dẫn (Đảm bảo biến môi trường vẫn đúng)
os.environ['nnUNet_raw'] = "/content/nnUNet_raw"
# !mkdir -p $nnUNet_raw

# Đường dẫn file zip trên Drive (Bạn kiểm tra lại tên file cho đúng nhé)
# Giả sử bạn lưu là nnUNet_raw.zip trong thư mục XUM_project
zip_path_drive = "/content/drive/MyDrive/XUM_project/nnUNET_raw.zip"
zip_local = "/content/nnUNet_raw.zip"
extract_root = "/content/nnUNet_raw"

if not os.path.exists(zip_path_drive):
    print(f"❌ Lỗi: Không tìm thấy file {zip_path_drive}")
    print("👉 Hãy kiểm tra lại tên file zip raw trên Google Drive của bạn.")
else:
    print("📦 Copy file Raw Data từ Drive...")
    # !cp "$zip_path_drive" "$zip_local"

    print("💨 Copy xong. Bắt đầu giải nén Raw Data...")

    with zipfile.ZipFile(zip_local, 'r') as zip_ref:
        # Detect folder root name inside zip (ví dụ: nnUNet_raw/)
        # Để tránh bị lồng thư mục kiểu /content/nnUNet_raw/nnUNet_raw/Dataset...
        root_name = zip_ref.namelist()[0].split('/')[0]

        file_list = zip_ref.infolist()
        total_files = len(file_list)

        print(f"🔧 Phát hiện folder root trong ZIP: {root_name}")
        print("🔧 Đang giải nén và loại bỏ lớp folder thừa...")

        for file in tqdm(file_list, total=total_files, desc="🔄 Unzipping Raw"):
            file_path = file.filename

            # Logic: Nếu file nằm trong folder root, ta bỏ tên root đi để file nhảy ra ngoài
            # Ví dụ: nnUNet_raw/Dataset101/abc.nii -> Dataset101/abc.nii
            if file_path.startswith(root_name + "/"):
                fixed_path = file_path.replace(root_name + "/", "", 1)
            else:
                fixed_path = file_path # Nếu nén không có folder root thì giữ nguyên

            if fixed_path.strip() == "":
                continue

            # Chỉ định nơi lưu đúng
            target_path = os.path.join(extract_root, fixed_path)

            # Tạo thư mục nếu cần
            if file.is_dir():
                os.makedirs(target_path, exist_ok=True)
            else:
                os.makedirs(os.path.dirname(target_path), exist_ok=True)
                with zip_ref.open(file) as source, open(target_path, "wb") as target:
                    target.write(source.read())

    os.remove(zip_local)
    print("🎉 ĐÃ GIẢI NÉN RAW DATA THÀNH CÔNG! SẴN SÀNG CHẠY INFERENCE! 🚀")
# Out:
# 📦 Copy file Raw Data từ Drive...
# 💨 Copy xong. Bắt đầu giải nén Raw Data...
# 🔧 Phát hiện folder root trong ZIP: nnUNET_raw
# 🔧 Đang giải nén và loại bỏ lớp folder thừa...
# 🔄 Unzipping Raw: 100%|██████████| 1845/1845 [03:57<00:00,  7.77it/s]
# 🎉 ĐÃ GIẢI NÉN RAW DATA THÀNH CÔNG! SẴN SÀNG CHẠY INFERENCE! 🚀

# %% [markdown]
# ## 2. Inference

# %%
# ------------------------------------------------------------------
# 🧠 CHẾ ĐỘ 1: CHẠY MODEL EDL (UNCERTAINTY DECOMPOSITION)
# ------------------------------------------------------------------
# Script này sẽ thực hiện quy trình full:
# 1. Tự động "tiêm" (inject) file EDLTrainer.py vào thư viện nnU-Net hệ thống.
# 2. Load trọng số Model EDL (checkpoint_best.pth) từ đường dẫn config 'edl'.
# 3. Chạy Inference và tính toán toán học để tách Uncertainty thành:
#    - Aleatoric (Nhiễu dữ liệu)
#    - Epistemic (Mô hình chưa biết)
# 4. Lưu kết quả Segmentation + 3 bản đồ Uncertainty (.nii.gz).
# !python "/content/drive/MyDrive/XUM_project/src/main.py" --mode edl
# Out:
# 🏁 --- STARTING PIPELINE | MODE: EDL | FOLD: 0 ---
# 🔧 Initializing Engine | Mode: EDL...
# 🚀 Initializing nnU-Net Predictor...
# 📂 Model loaded from: /content/drive/MyDrive/XUM_project/nnUNet_results/Dataset101_BraTS2020/EDLTrainer__nnUNetPlans__3d_fullres
# 📂 Đã load danh sách Validation Fold 0: 74 ca.
# ⚙️ Mode: VALIDATION SPLIT -> Found 74 cases (Filtered).
#
# =====================================================================================
# Index    | Case ID         | Dice WT  | Dice TC  | Dice ET  | Mean
# -------------------------------------------------------------------------------------
# 100% 8/8 [00:16<00:00,  2.10s/it]
# 1        | BRATS_011       | 0.9184   | 0.9098   | 0.7531   | 0.8604
#     📸 Drawing Slice: 111
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_011_slice111_viz.png
# 100% 8/8 [00:16<00:00,  2.02s/it]
# 2        | BRATS_012       | 0.8588   | 0.9274   | 0.8367   | 0.8743
#     📸 Drawing Slice: 119
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_012_slice119_viz.png
# 100% 8/8 [00:16<00:00,  2.04s/it]
# 3        | BRATS_019       | 0.9011   | 0.9241   | 0.7890   | 0.8714
#     📸 Drawing Slice: 104
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_019_slice104_viz.png
# 100% 8/8 [00:16<00:00,  2.08s/it]
# 4        | BRATS_020       | 0.8916   | 0.8629   | 0.6994   | 0.8180
#     📸 Drawing Slice: 45
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_020_slice45_viz.png
# 100% 8/8 [00:16<00:00,  2.10s/it]
# 5        | BRATS_021       | 0.7972   | 0.8907   | 0.6509   | 0.7796
#     📸 Drawing Slice: 58
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_021_slice58_viz.png
# 100% 4/4 [00:08<00:00,  2.11s/it]
# 6        | BRATS_023       | 0.9122   | 0.9553   | 0.8776   | 0.9151
#     📸 Drawing Slice: 82
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_023_slice82_viz.png
# 100% 8/8 [00:17<00:00,  2.15s/it]
# 7        | BRATS_028       | 0.8572   | 0.8646   | 0.6473   | 0.7897
#     📸 Drawing Slice: 113
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_028_slice113_viz.png
# 100% 8/8 [00:17<00:00,  2.19s/it]
# 8        | BRATS_029       | 0.9361   | 0.9437   | 0.8776   | 0.9191
#     📸 Drawing Slice: 33
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_029_slice33_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 9        | BRATS_032       | 0.9031   | 0.9041   | 0.7945   | 0.8672
#     📸 Drawing Slice: 82
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_032_slice82_viz.png
# 100% 8/8 [00:17<00:00,  2.15s/it]
# 10       | BRATS_036       | 0.8828   | 0.8790   | 0.8240   | 0.8620
#     📸 Drawing Slice: 122
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_036_slice122_viz.png
# 100% 4/4 [00:08<00:00,  2.16s/it]
# 11       | BRATS_039       | 0.9222   | 0.9364   | 0.8797   | 0.9128
#     📸 Drawing Slice: 96
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_039_slice96_viz.png
# 100% 8/8 [00:17<00:00,  2.20s/it]
# 12       | BRATS_041       | 0.9431   | 0.8931   | 0.7478   | 0.8613
#     📸 Drawing Slice: 38
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_041_slice38_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 13       | BRATS_042       | 0.9571   | 0.9630   | 0.8717   | 0.9306
#     📸 Drawing Slice: 90
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_042_slice90_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 14       | BRATS_049       | 0.9179   | 0.9428   | 0.8545   | 0.9051
#     📸 Drawing Slice: 94
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_049_slice94_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 15       | BRATS_051       | 0.9416   | 0.9468   | 0.8855   | 0.9246
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_051_slice40_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 16       | BRATS_053       | 0.9556   | 0.8611   | 0.8056   | 0.8741
#     📸 Drawing Slice: 31
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_053_slice31_viz.png
# 100% 4/4 [00:08<00:00,  2.14s/it]
# 17       | BRATS_056       | 0.8815   | 0.9266   | 0.8727   | 0.8936
#     📸 Drawing Slice: 51
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_056_slice51_viz.png
# 100% 4/4 [00:08<00:00,  2.15s/it]
# 18       | BRATS_069       | 0.7501   | 0.9449   | 0.8150   | 0.8367
#     📸 Drawing Slice: 81
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_069_slice81_viz.png
# 100% 8/8 [00:17<00:00,  2.19s/it]
# 19       | BRATS_074       | 0.8261   | 0.5019   | 0.4247   | 0.5842
#     📸 Drawing Slice: 94
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_074_slice94_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 20       | BRATS_086       | 0.7978   | 0.2777   | 0.4213   | 0.4989
#     📸 Drawing Slice: 9
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_086_slice9_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 21       | BRATS_088       | 0.8511   | 0.9182   | 0.8404   | 0.8699
#     📸 Drawing Slice: 31
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_088_slice31_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 22       | BRATS_089       | 0.8402   | 0.9694   | 0.9673   | 0.9256
#     📸 Drawing Slice: 99
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_089_slice99_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 23       | BRATS_098       | 0.9819   | 0.9628   | 0.8843   | 0.9430
#     📸 Drawing Slice: 56
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_098_slice56_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 24       | BRATS_100       | 0.9621   | 0.9559   | 0.8715   | 0.9298
#     📸 Drawing Slice: 36
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_100_slice36_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 25       | BRATS_101       | 0.9270   | 0.9131   | 0.8818   | 0.9073
#     📸 Drawing Slice: 108
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_101_slice108_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 26       | BRATS_104       | 0.9674   | 0.9569   | 0.9350   | 0.9531
#     📸 Drawing Slice: 29
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_104_slice29_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 27       | BRATS_107       | 0.9528   | 0.9592   | 0.9585   | 0.9568
#     📸 Drawing Slice: 86
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_107_slice86_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 28       | BRATS_111       | 0.9535   | 0.9602   | 0.9148   | 0.9429
#     📸 Drawing Slice: 30
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_111_slice30_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 29       | BRATS_113       | 0.9613   | 0.5913   | 0.7119   | 0.7548
#     📸 Drawing Slice: 29
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_113_slice29_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 30       | BRATS_114       | 0.9470   | 0.9702   | 0.9077   | 0.9416
#     📸 Drawing Slice: 85
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_114_slice85_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 31       | BRATS_116       | 0.9706   | 0.9788   | 0.9268   | 0.9587
#     📸 Drawing Slice: 37
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_116_slice37_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 32       | BRATS_131       | 0.9225   | 0.8773   | 0.8877   | 0.8958
#     📸 Drawing Slice: 86
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_131_slice86_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 33       | BRATS_137       | 0.9431   | 0.9418   | 0.8640   | 0.9163
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_137_slice40_viz.png
# 100% 4/4 [00:08<00:00,  2.16s/it]
# 34       | BRATS_138       | 0.9392   | 0.8142   | 0.9000   | 0.8845
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_138_slice40_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 35       | BRATS_145       | 0.9302   | 0.9159   | 0.8128   | 0.8863
#     📸 Drawing Slice: 109
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_145_slice109_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 36       | BRATS_149       | 0.9277   | 0.8772   | 0.8473   | 0.8841
#     📸 Drawing Slice: 103
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_149_slice103_viz.png
# 100% 2/2 [00:04<00:00,  2.11s/it]
# 37       | BRATS_150       | 0.9579   | 0.9635   | 0.9553   | 0.9589
#     📸 Drawing Slice: 87
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_150_slice87_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 38       | BRATS_153       | 0.9441   | 0.9629   | 0.9472   | 0.9514
#     📸 Drawing Slice: 108
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_153_slice108_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 39       | BRATS_155       | 0.9708   | 0.9681   | 0.9427   | 0.9606
#     📸 Drawing Slice: 87
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_155_slice87_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 40       | BRATS_161       | 0.9523   | 0.9324   | 0.8597   | 0.9148
#     📸 Drawing Slice: 56
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_161_slice56_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 41       | BRATS_174       | 0.9759   | 0.9549   | 0.9324   | 0.9544
#     📸 Drawing Slice: 96
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_174_slice96_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 42       | BRATS_175       | 0.9531   | 0.9356   | 0.9113   | 0.9333
#     📸 Drawing Slice: 86
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_175_slice86_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 43       | BRATS_181       | 0.9389   | 0.9370   | 0.9267   | 0.9342
#     📸 Drawing Slice: 86
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_181_slice86_viz.png
# 100% 4/4 [00:08<00:00,  2.15s/it]
# 44       | BRATS_187       | 0.9639   | 0.9477   | 0.8846   | 0.9320
#     📸 Drawing Slice: 32
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_187_slice32_viz.png
# 100% 8/8 [00:17<00:00,  2.19s/it]
# 45       | BRATS_191       | 0.9375   | 0.9311   | 0.9216   | 0.9301
#     📸 Drawing Slice: 50
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_191_slice50_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 46       | BRATS_196       | 0.9447   | 0.9537   | 0.9373   | 0.9452
#     📸 Drawing Slice: 94
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_196_slice94_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 47       | BRATS_203       | 0.9111   | 0.9054   | 0.8536   | 0.8900
#     📸 Drawing Slice: 109
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_203_slice109_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 48       | BRATS_205       | 0.9000   | 0.9403   | 0.9166   | 0.9190
#     📸 Drawing Slice: 107
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_205_slice107_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 49       | BRATS_207       | 0.9225   | 0.8841   | 0.8121   | 0.8729
#     📸 Drawing Slice: 119
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_207_slice119_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 50       | BRATS_214       | 0.9669   | 0.9229   | 0.9074   | 0.9324
#     📸 Drawing Slice: 25
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_214_slice25_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 51       | BRATS_223       | 0.9753   | 0.9592   | 0.9448   | 0.9598
#     📸 Drawing Slice: 55
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_223_slice55_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 52       | BRATS_224       | 0.9606   | 0.9539   | 0.9155   | 0.9433
#     📸 Drawing Slice: 108
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_224_slice108_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 53       | BRATS_226       | 0.9451   | 0.9524   | 0.9287   | 0.9421
#     📸 Drawing Slice: 97
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_226_slice97_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 54       | BRATS_229       | 0.9642   | 0.9581   | 0.9447   | 0.9557
#     📸 Drawing Slice: 82
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_229_slice82_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 55       | BRATS_239       | 0.9061   | 0.7297   | 0.7788   | 0.8048
#     📸 Drawing Slice: 67
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_239_slice67_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 56       | BRATS_244       | 0.9589   | 0.9357   | 0.7792   | 0.8913
#     📸 Drawing Slice: 31
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_244_slice31_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 57       | BRATS_251       | 0.9614   | 0.9534   | 0.9468   | 0.9538
#     📸 Drawing Slice: 108
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_251_slice108_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 58       | BRATS_266       | 0.9452   | 0.7855   | 0.0000   | 0.5769
#     📸 Drawing Slice: 106
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_266_slice106_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 59       | BRATS_285       | 0.9665   | 0.9361   | 0.6382   | 0.8469
#     📸 Drawing Slice: 83
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_285_slice83_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 60       | BRATS_299       | 0.9608   | 0.9559   | 0.5622   | 0.8263
#     📸 Drawing Slice: 104
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_299_slice104_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 61       | BRATS_301       | 0.8964   | 0.6266   | 0.5568   | 0.6933
#     📸 Drawing Slice: 82
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_301_slice82_viz.png
# 100% 4/4 [00:08<00:00,  2.17s/it]
# 62       | BRATS_304       | 0.9078   | 0.8362   | 0.0000   | 0.5814
#     📸 Drawing Slice: 40
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_304_slice40_viz.png
# 100% 8/8 [00:17<00:00,  2.18s/it]
# 63       | BRATS_308       | 0.9403   | 0.7756   | 0.7524   | 0.8227
#     📸 Drawing Slice: 62
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_308_slice62_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 64       | BRATS_328       | 0.9155   | 0.5730   | 0.3537   | 0.6141
#     📸 Drawing Slice: 64
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_328_slice64_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 65       | BRATS_330       | 0.9591   | 0.8898   | 0.0000   | 0.6163
#     📸 Drawing Slice: 101
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_330_slice101_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 66       | BRATS_341       | 0.8788   | 0.9585   | 0.9550   | 0.9308
#     📸 Drawing Slice: 123
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_341_slice123_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 67       | BRATS_343       | 0.9412   | 0.9498   | 0.9051   | 0.9320
#     📸 Drawing Slice: 35
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_343_slice35_viz.png
# 100% 4/4 [00:08<00:00,  2.14s/it]
# 68       | BRATS_349       | 0.9540   | 0.9636   | 0.9117   | 0.9431
#     📸 Drawing Slice: 54
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_349_slice54_viz.png
# 100% 8/8 [00:17<00:00,  2.19s/it]
# 69       | BRATS_352       | 0.9432   | 0.9311   | 0.9180   | 0.9307
#     📸 Drawing Slice: 30
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_352_slice30_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 70       | BRATS_354       | 0.9656   | 0.9688   | 0.9422   | 0.9588
#     📸 Drawing Slice: 46
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_354_slice46_viz.png
# 100% 8/8 [00:17<00:00,  2.16s/it]
# 71       | BRATS_356       | 0.9139   | 0.9457   | 0.9032   | 0.9209
#     📸 Drawing Slice: 92
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_356_slice92_viz.png
# 100% 2/2 [00:04<00:00,  2.09s/it]
# 72       | BRATS_360       | 0.8651   | 0.9662   | 0.9250   | 0.9187
#     📸 Drawing Slice: 38
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_360_slice38_viz.png
# 100% 8/8 [00:17<00:00,  2.17s/it]
# 73       | BRATS_368       | 0.9633   | 0.9533   | 0.9359   | 0.9509
#     📸 Drawing Slice: 105
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_368_slice105_viz.png
# 100% 8/8 [00:17<00:00,  2.19s/it]
# 74       | BRATS_369       | 0.9623   | 0.9176   | 0.9198   | 0.9333
#     📸 Drawing Slice: 63
#     ✅ Saved Snapshot: /content/drive/MyDrive/XUM_project/inference_results_edl/BRATS_369_slice63_viz.png
#
# ============================================================
#                  📊 FINAL SUMMARY (AVERAGE)
# ------------------------------------------------------------
# Metric          | WT         | TC         | ET
# ------------------------------------------------------------
# Dice Score      | 0.9259     | 0.8964     | 0.8050
# HD95 (mm)       | 5.4782     | 3.4807     | 3.2738
# ------------------------------------------------------------
# Overall Mean Dice: 0.8758
# ✅ Report saved to: /content/drive/MyDrive/XUM_project/inference_results_edl
#
# ✅ --- PIPELINE COMPLETED ---

# %%
# Test thử trên 5 ca đầu tiên cho nhanh
# !python /content/drive/MyDrive/XUM_project/src/analysis_ause.py --mode edl
# Out:
# 🚀 BẮT ĐẦU PHÂN TÍCH CHUẨN RESEARCH (V9) | MODE: EDL
# 🔍 Found 74 cases.
#
# 📊 Analyzing Class: WT ...
# Processing WT: 100% 74/74 [01:11<00:00,  1.04it/s]
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:252: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_total = np.trapz(mean_opt - mean_dice, dx=1.0/len(valid_retention))
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:257: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_alea = np.trapz(mean_opt - mean_alea, dx=1.0/len(valid_retention))
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:262: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_epis = np.trapz(mean_opt - mean_epis, dx=1.0/len(valid_retention))
#
# 📊 Analyzing Class: TC ...
# Processing TC: 100% 74/74 [01:14<00:00,  1.00s/it]
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:252: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_total = np.trapz(mean_opt - mean_dice, dx=1.0/len(valid_retention))
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:257: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_alea = np.trapz(mean_opt - mean_alea, dx=1.0/len(valid_retention))
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:262: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_epis = np.trapz(mean_opt - mean_epis, dx=1.0/len(valid_retention))
#
# 📊 Analyzing Class: ET ...
# Processing ET: 100% 74/74 [01:10<00:00,  1.05it/s]
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:252: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_total = np.trapz(mean_opt - mean_dice, dx=1.0/len(valid_retention))
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:257: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_alea = np.trapz(mean_opt - mean_alea, dx=1.0/len(valid_retention))
# /content/drive/MyDrive/XUM_project/src/analysis_ause.py:262: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   ause_epis = np.trapz(mean_opt - mean_epis, dx=1.0/len(valid_retention))
#
# ================================================================================
#                 🏆 FINAL METRICS REPORT (V9 - RESEARCH STANDARD)
# ================================================================================
# Class  QU_Score  AUSE_Total  AUSE_Aleatoric  AUSE_Epistemic
#    WT    0.4843      0.2793          0.3168          0.1629
#    TC    0.5353      0.0849          0.1071          0.0838
#    ET    0.5504      0.0679          0.0869          0.0720
# --------------------------------------------------------------------------------
# ✅ Report saved to: /content/drive/MyDrive/XUM_project/inference_results_edl/analysis_research_v9
